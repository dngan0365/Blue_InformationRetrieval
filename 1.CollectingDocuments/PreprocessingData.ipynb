# %%
import os
import re
import csv
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin, urlparse
import requests

# %%
# Cấu hình đường dẫn
INPUT_FOLDER = "data"  
OUTPUT_FOLDER = "data_clean"  
URLS_CSV = "extracted_urls.csv"  

# Tạo thư mục output nếu chưa tồn tại
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %%
def remove_ads(soup):
    clean_soup = BeautifulSoup(str(soup), 'html.parser')
    
    # Xóa các tag chứa quảng cáo dựa trên class hoặc id
    ad_keywords = ['ad', 'banner', 'promo', 'sponsor', 'popup', 'advert']
    for keyword in ad_keywords:
        for element in clean_soup.find_all(attrs={"class": re.compile(keyword, re.I)}):
            element.decompose()
        for element in clean_soup.find_all(attrs={"id": re.compile(keyword, re.I)}):
            element.decompose()

    return clean_soup

# %%
# HÀM LOẠI BỎ CÁC THÀNH PHẦN KHÔNG CẦN THIẾT
def remove_unwanted_elements(soup):

    # Tạo bản sao để không làm hỏng soup gốc
    clean_soup = BeautifulSoup(str(soup), 'html.parser')
    
    elements_to_remove = [
        'script', 'style', 'link', 'meta', 'noscript', 'footer', 'nav', 'aside', 'iframe', 'img', 'svg', 'picture', 'video', 'audio', 'button',
    ]
    
    for tag in elements_to_remove:
        for element in clean_soup.find_all(tag):
            element.decompose()

    return clean_soup

# %%
# HÀM TRÍCH XUẤT NỘI DUNG CHÍNH
def extract_main_content(soup):
    all_content = []

    # Các tag thường chứa nội dung quan trọng
    content_tags = ['title', 'p', 'h1','h2','h3','h4','h5','h6','li','blockquote','pre','code','td','th','caption','figcaption','summary','dt','dd']
    
    for elem in soup.find_all(content_tags):
        text = elem.get_text(separator=' ', strip=True)
        # Chỉ giữ text dài hơn 20 ký tự để loại bỏ rác
        all_content.append(text)
    
    return '\n'.join(all_content)  # mỗi block cách nhau 2 dòng cho dễ đọc

# %%
# HÀM CHỈNH SỬA TEXT
def normalize_text(text):
    if not text:
        return ""
    
    # Chuẩn hóa khoảng trắng
    text = re.sub(r'\s+', ' ', text)
    
    # Sửa lỗi dấu câu cơ bản
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)  # bỏ khoảng trắng trước dấu câu
    text = re.sub(r'([.,!?;:])(\w)', r'\1 \2', text)  # thêm khoảng trắng sau dấu câu nếu thiếu
    
    # Loại bỏ ký tự đặc biệt, giữ lại dấu câu tiếng Việt
    text = re.sub(r'[^\w\s.,!?;:()\-ÀÁÂÃÈÉÊÌÍÒÓÔÕÙÚÝàáâãèéêìíòóôõùúýĂăĐđĨĩŨũƠơƯưẠ-ỹ]', ' ', text)

    # Chuẩn hóa khoảng trắng lần cuối
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# %%
# 1. Đọc file CSV
csv_file = "info.csv"
df = pd.read_csv(csv_file)
df
# Out:
#       id                                                url  \
# 0      0  https://vnexpress.net/cam-nang-du-lich-an-gian...
# 1      1  https://vnexpress.net/cam-nang-du-lich-ba-na-h...
# 2      2  https://vnexpress.net/cam-nang-du-lich-bac-gia...
# 3      3  https://vnexpress.net/cam-nang-du-lich-binh-th...
# 4      4  https://vnexpress.net/cam-nang-du-lich-binh-di...
# ..   ...                                                ...
# 488  491  https://vinwonders.com/vi/wonderpedia/news/tha...
# 489  492  https://www.ivivu.com/blog/2023/05/kham-pha-th...
# 490  493  https://mia.vn/cam-nang-du-lich/kham-pha-mai-c...
# 491  494  https://mia.vn/cam-nang-du-lich/kham-pha-nha-t...
# 492  495  https://www.ivivu.com/blog/2024/10/nha-tho-go-...
#
#                                                  title
# 0                            Cẩm nang du lịch An Giang
# 1                         Cẩm nang du lịch Bà Nà Hills
# 2                           Cẩm nang du lịch Bắc Giang
# 3                          Cẩm nang du lịch Bình Thuận
# 4                           Cẩm nang du lịch Bình Định
# ..                                                 ...
# 488                                   Just a moment...
# 489  Khám phá thung lũng Mai Châu đẹp lãng mạn tại ...
# 490       Khám phá Mai Châu Hòa Bình có gì cùng MIA.vn
# 491  Khám phá Nhà thờ gỗ Kon Tum với tuổi đời hơn 1...
# 492  Nhà thờ gỗ Kontum hơn trăm tuổi cổ kính uy nghiêm
#
# [493 rows x 3 columns]

# %%
# Tạo dict id -> url
id_to_url = dict(zip(df['id'], df['url']))

# 2. Lấy base_url từ CSV
def get_base_url(file_id):
    """
    Lấy domain gốc từ URL tương ứng trong CSV
    ví dụ: https://vnexpress.net/cam-nang-du-lich-an-giang-4445399.html -> https://vnexpress.net
    """
    url = id_to_url.get(file_id)
    if url:
        parsed = urlparse(url)
        return f"{parsed.scheme}://{parsed.netloc}"
    return None

# %%
# Tạo set các URL trong CSV để lọc
valid_urls = set(df['url'].tolist())

# %%
from urllib.parse import urlparse, urljoin

# 2. Hàm kiểm tra URL hợp lệ
def is_valid_url(url):
    try:
        parsed = urlparse(url)
        return bool(parsed.netloc) and bool(parsed.scheme)
    except:
        return False

# 3. Hàm trích xuất URL từ soup, chỉ giữ URL trong CSV
def extract_related_urls(soup, base_url):
    urls = []
    for link in soup.find_all('a', href=True):
        url = link['href'].strip()
        
        # Bỏ các link rác
        if url.startswith(('javascript:', 'mailto:', 'tel:', '#', 'void(0)')) or len(url) <= 5:
            continue
        
        # Chuẩn hóa URL
        if url.startswith('/'):
            url = urljoin(base_url, url)
        elif not url.startswith(('http://', 'https://')):
            url = urljoin(base_url + '/', url)
        
        # Chỉ giữ URL xuất hiện trong CSV
        if is_valid_url(url) and url in valid_urls:
            urls.append(url)
    
    return list(set(urls))  # loại bỏ trùng lặp

# %%
# HÀM XỬ LÝ FILE HTML CHÍNH
import os
from bs4 import BeautifulSoup

def process_html_file(html_file_path, base_url=None, valid_urls=None, file_id=None):
    """
    Xử lý 1 file HTML:
    - Lọc quảng cáo/rác
    - Lấy text chính
    - Chuẩn hóa text
    - Trích xuất URL liên quan (chỉ những URL có trong valid_urls)
    
    Args:
        html_file_path: đường dẫn file HTML
        base_url: domain gốc để chuẩn hóa URL
        valid_urls: danh sách URL hợp lệ để lọc
        file_id: ID file, để gắn metadata
    """
    try:
        # Đọc file HTML
        with open(html_file_path, 'r', encoding='utf-8', errors='ignore') as file:
            html_content = file.read()
        
        soup = BeautifulSoup(html_content, 'html.parser')
        
        # Lấy tiêu đề trang
        title = soup.title.string if soup.title else os.path.basename(html_file_path)
        
        # Lọc rác và quảng cáo
        clean_soup = remove_ads(soup)
        clean_soup = remove_unwanted_elements(clean_soup)
        
        # Lưu HTML đã lọc
        html_clean_folder = "html_clean"
        os.makedirs(html_clean_folder, exist_ok=True)
        clean_html_filename = os.path.basename(html_file_path)
        clean_html_path = os.path.join(html_clean_folder, clean_html_filename)
        
        with open(clean_html_path, 'w', encoding='utf-8') as file:
            file.write(str(clean_soup))
        
        # Lấy nội dung chính
        clean_text = extract_main_content(clean_soup)
        
        if clean_text and len(clean_text) > 0:
            clean_text = normalize_text(clean_text)
            
            # Trích xuất URL liên quan, chỉ những URL hợp lệ
            urls = []
            if base_url and valid_urls:
                urls = extract_related_urls(soup, base_url=base_url)
                # Lọc chỉ giữ URL có trong danh sách valid_urls
                urls = [u for u in urls if u in valid_urls]
            
            return {
                'file_id': file_id,
                'title': title,
                'clean_text': clean_text,
                'urls': urls,
                'clean_length': len(clean_text),
                'success': True,
            }
        else:
            return {
                'file_id': file_id,
                'title': title,
                'clean_text': "",
                'urls': [],
                'clean_length': 0,
                'success': False,
            }
            
    except Exception as e:
        print(f"Lỗi xử lý {html_file_path}: {str(e)}")
        return {
            'file_id': file_id,
            'title': os.path.basename(html_file_path),
            'clean_text': "",
            'urls': [],
            'clean_length': 0,
            'success': False,
        }

# %%
# 3. Ví dụ sử dụng với process_html_file
file_id = 0
html_file_path = f"./data/{file_id}.html"
base_url = get_base_url(file_id)

result = process_html_file(
    html_file_path,
    base_url=base_url,
    valid_urls=set(df['url'].tolist()),
    file_id=file_id
)

print(result)
# Out:
# {'file_id': 0, 'title': 'Cẩm nang du lịch An Giang 2024: 12 địa điểm vui chơi phải trải nghiệm', 'clean_text': 'Cẩm nang du lịch An Giang 2024: 12 địa điểm vui chơi phải trải nghiệm An Giang 3 Trở lại Du lịch Điều hướng nhanh An Giang mùa nào đẹp? Di chuyển Chơi đâu Khách sạn, homestay Đặc sản An Giang Mua gì làm quà An Giang là tỉnh ở miền Tây Nam Bộ, một phần trong vùng tứ giác Long Xuyên. Tỉnh thuộc vùng đồng bằng sông Cửu Long, có sông Tiền và sông Hậu chảy qua. Đường biên giới dài gần 100 km giáp Campuchia. An Giang mùa nào đẹp? Từ tháng 3 đến tháng 5, An Giang trong mùa nắng khô ráo. Nếu muốn ngắm thảm bèo cũng như thế giới tự nhiên xanh mát ở rừng tràm Trà Sư vào mùa nước nổi, bạn nên đi vào tháng 10 và 11. Cuối tháng 11 đến đầu tháng 12, bạn có thể chiêm ngưỡng những cánh đồng lúa chín vào mùa gặt ở Tà Pạ. Vào tháng 4 hay tháng 8 âm lịch là thời gian diễn ra hai lễ hội lớn gồm hội bà Chúa Xứ núi Sam (23 - 27/4 âm lịch) và lễ hội đua bò cuối tháng 8. Các tháng 7 - 8 có mưa khá nhiều nên bạn cần mang theo ô và trang phục phù hợp. Di chuyển Nếu di chuyển bằng đường hàng không, sân bay ở TP HCM và Cần Thơ là điểm đến gần nhất, sau đó du khách đi xe khách đến thành phố Long
chùa Tây An Chùa Tây An nằm ở chân núi Sam (xã Vĩnh Tế, thành phố Châu Đốc) xây dựng vào năm 1847, mang dáng dấp của một công trình kiến trúc Ấn Độ. Ngôi cổ tự đã được Bộ Văn hóa xếp hạng là di tích kiến trúc nghệ thuật cấp quốc gia. Đây cũng là ngôi chùa mang kiến trúc Việt kết hợp với Ấn Độ đầu tiên ở Việt Nam. Chợ Châu Đốc được xem như "vương quốc mắm". Ảnh: Quỳnh Trần Chợ Châu Đốc Chợ nằm ở trung tâm thành phố Châu Đốc, bán cá ...

# %%
# HÀM XỬ LÝ TẤT CẢ FILE VÀ LƯU KẾT QUẢ THEO TÊN
def process_all_html_files():
    """
    Xử lý tất cả file HTML trong thư mục data
    """
    html_files = [f for f in os.listdir(INPUT_FOLDER) if f.endswith(('.html', '.htm'))]
    
    all_results = []
    url_data = []
    
    print(f"Bắt đầu xử lý {len(html_files)} file HTML...")
    print("=" * 60)
    
    for i, html_file in enumerate(html_files, 1):
        input_path = os.path.join(INPUT_FOLDER, html_file)
        output_filename = html_file.rsplit('.', 1)[0] + '.txt'
        output_path = os.path.join(OUTPUT_FOLDER, output_filename)
        
        print(f"[{i}/{len(html_files)}] Đang xử lý: {html_file}")
        
        file_id = int(html_file.rsplit('.', 1)[0])  # giả sử tên file là id.html
        base_url = get_base_url(file_id)
        result = process_html_file(input_path, base_url=base_url, valid_urls=valid_urls, file_id=file_id)
        
        # Lưu file TXT
        if result['success'] and result['clean_text']:
            with open(output_path, 'w', encoding='utf-8') as file:
                file.write(result['clean_text'])
        
        for url in result['urls']:
            url_data.append({
                'title': result['title'],
                'url': url,
                'source_file': html_file
            })

        
        all_results.append(result)
        
        print(f"Nội dung: {result['clean_length']} ký tự")
        print(f"URL: {len(result['urls'])} liên kết")
    
    # LƯU FILE CSV CHỨA URL LIÊN QUAN
    if url_data:
        df_urls = pd.DataFrame(url_data)
        df_urls.to_csv(URLS_CSV, index=False, encoding='utf-8')
        print(f"\nĐã lưu {len(url_data)} URL vào: {URLS_CSV}")
    
    return all_results

results = process_all_html_files()
# Out:
# Bắt đầu xử lý 493 file HTML...
# ============================================================
# [1/493] Đang xử lý: 0.html
# Nội dung: 9722 ký tự
# URL: 1 liên kết
# [2/493] Đang xử lý: 1.html
# Nội dung: 14313 ký tự
# URL: 2 liên kết
# [3/493] Đang xử lý: 10.html
# Nội dung: 9866 ký tự
# URL: 2 liên kết
# [4/493] Đang xử lý: 100.html
# Nội dung: 13143 ký tự
# URL: 1 liên kết
# [5/493] Đang xử lý: 101.html
# Nội dung: 16374 ký tự
# URL: 1 liên kết
# [6/493] Đang xử lý: 102.html
# Nội dung: 13522 ký tự
# URL: 0 liên kết
# [7/493] Đang xử lý: 103.html
# Nội dung: 14930 ký tự
# URL: 0 liên kết
# [8/493] Đang xử lý: 104.html
# Nội dung: 17115 ký tự
# URL: 1 liên kết
# [9/493] Đang xử lý: 105.html
# Nội dung: 8400 ký tự
# URL: 2 liên kết
# [10/493] Đang xử lý: 106.html
# Nội dung: 10046 ký tự
# URL: 2 liên kết
# [11/493] Đang xử lý: 107.html
# Nội dung: 11004 ký tự
# URL: 4 liên kết
# [12/493] Đang xử lý: 108.html
# Nội dung: 16749 ký tự
# URL: 1 liên kết
# [13/493] Đang xử lý: 109.html
# Nội dung: 23931 ký tự
# URL: 5 liên kết
# [14/493] Đang xử lý: 11.html
# Nội dung: 16011 ký tự
# URL: 5 liên kết
# [15/493] Đang xử lý: 110.html
# Nội dung: 14626 ký tự
# URL: 3 liên kết
# [16/493] Đang xử lý: 111.html
# Nội dung: 7944 ký tự
# URL: 3 liên kết
# [17/493] Đang xử lý: 112.html
# Nội dung: 8765 ký tự
# URL: 2 liên kết
# [18/493] Đang xử lý: 113.html
# Nội dung: 10309 ký tự
# URL: 2 liên kết
# [19/493] Đang xử lý: 114.html
# Nội dung: 24252 ký tự
# URL: 3 liên kết
# [20/493] Đang xử lý: 115.html
# Nội dung: 3444 ký tự
# URL: 0 liên kết
# [21/493] Đang xử lý: 116.html
# Nội dung: 10059 ký tự
# URL: 2 liên kết
# [22/493] Đang xử lý: 117.html
# Nội dung: 11810 ký tự
# URL: 2 liên kết
# [23/493] Đang xử lý: 118.html
# Nội dung: 15757 ký tự
# URL: 1 liên kết
# [24/493] Đang xử lý: 119.html
# Nội dung: 10749 ký tự
# URL: 2 liên kết
# [25/493] Đang xử lý: 12.html
# Nội dung: 12293 ký tự
# URL: 1 liên kết
# [26/493] Đang xử lý: 120.html
# Nội dung: 16841 ký tự
# URL: 1 liên kết
# [27/493] Đang xử lý: 121.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [28/493] Đang xử lý: 122.html
# Nội dung: 11734 ký tự
# URL: 3 liên kết
# [29/493] Đang xử lý: 123.html
# Nội dung: 18601 ký tự
# URL: 2 liên kết
# [30/493] Đang xử lý: 124.html
# Nội dung: 9076 ký tự
# URL: 3 liên kết
# [31/493] Đang xử lý: 125.html
# Nội dung: 8259 ký tự
# URL: 1 liên kết
# [32/493] Đang xử lý: 126.html
# Nội dung: 16190 ký tự
# URL: 5 liên kết
# [33/493] Đang xử lý: 127.html
# Nội dung: 9743 ký tự
# URL: 0 liên kết
# [34/493] Đang xử lý: 128.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [35/493] Đang xử lý: 129.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [36/493] Đang xử lý: 13.html
# Nội dung: 11171 ký tự
# URL: 2 liên kết
# [37/493] Đang xử lý: 130.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [38/493] Đang xử lý: 131.html
# Nội dung: 9057 ký tự
# URL: 1 liên kết
# [39/493] Đang xử lý: 132.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [40/493] Đang xử lý: 133.html
# Nội dung: 17031 ký tự
# URL: 0 liên kết
# [41/493] Đang xử lý: 134.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [42/493] Đang xử lý: 135.html
# Nội dung: 13959 ký tự
# URL: 1 liên kết
# [43/493] Đang xử lý: 136.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [44/493] Đang xử lý: 137.html
# Nội dung: 13590 ký tự
# URL: 0 liên kết
# [45/493] Đang xử lý: 138.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [46/493] Đang xử lý: 139.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
#
html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [109/493] Đang xử lý: 196.html
# Nội dung: 649 ký tự
# URL: 0 liên kết
# [110/493] Đang xử lý: 197.html
# Nội dung: 108 ký tự
# URL: 0 liên kết
# [111/493] Đang xử lý: 198.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [112/493] Đang xử lý: 199.html
# Nội dung: 17089 ký tự
# URL: 1 liên kết
# [113/493] Đang xử lý: 2.html
# Nội dung: 12933 ký tự
# URL: 1 liên kết
# [114/493] Đang xử lý: 20.html
# Nội dung: 14431 ký tự
# URL: 3 liên kết
# [115/493] Đang xử lý: 200.html
# Nội dung: 3675 ký tự
# URL: 0 liên kết
# [116/493] Đang xử lý: 201.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [117/493] Đang xử lý: 202.html
# Nội dung: 832 ký tự
# URL: 0 liên kết
# [118/493] Đang xử lý: 203.html
# Nội dung: 9139 ký tự
# URL: 1 liên kết
# [119/493] Đang xử lý: 204.html
# Nội dung: 2758 ký tự
# URL: 0 liên kết
# [120/493] Đang xử lý: 205.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [121/493] Đang xử lý: 206.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [122/493] Đang xử lý: 207.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [123/493] Đang xử lý: 208.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [124/493] Đang xử lý: 209.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [125/493] Đang xử lý: 21.html
# Nội dung: 11341 ký tự
# URL: 2 liên kết
# [126/493] Đang xử lý: 210.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [127/493] Đang xử lý: 211.html
# Nội dung: 10066 ký tự
# URL: 0 liên kết
# [128/493] Đang xử lý: 212.html
# Nội dung: 12681 ký tự
# URL: 0 liên kết
# [129/493] Đang xử lý: 213.html
# Nội dung: 4506 ký tự
# URL: 1 liên kết
# [130/493] Đang xử lý: 214.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [131/493] Đang xử lý: 215.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [132/493] Đang xử lý: 216.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [133/493] Đang xử lý: 217.html
# Nội dung: 11144 ký tự
# URL: 0 liên kết
# [134/493] Đang xử lý: 218.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [135/493] Đang xử lý: 219.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [136/493] Đang xử lý: 22.html
# Nội dung: 7652 ký tự
# URL: 1 liên kết
# [137/493] Đang xử lý: 220.html
# Nội dung: 10356 ký tự
# URL: 1 liên kết
# [138/493] Đang xử lý: 221.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [139/493] Đang xử lý: 222.html
# Nội dung: 12263 ký tự
# URL: 0 liên kết
# [140/493] Đang xử lý: 223.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [141/493] Đang xử lý: 224.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [142/493] Đang xử lý: 225.html
# Nội dung: 8440 ký tự
# URL: 1 liên kết
# [143/493] Đang xử lý: 226.html
# Nội dung: 6983 ký tự
# URL: 0 liên kết
# [144/493] Đang xử lý: 227.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [145/493] Đang xử lý: 228.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [146/493] Đang xử lý: 229.html
# Nội dung: 9527 ký tự
# URL: 0 liên kết
# [147/493] Đang xử lý: 23.html
# Nội dung: 12147 ký tự
# URL: 2 liên kết
# [148/493] Đang xử lý: 230.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [149/493] Đang xử lý: 231.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [150/493] Đang xử lý: 232.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [151/493] Đang xử lý: 233.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [152/493] Đang xử lý: 234.html
# Nội dung: 6910 ký tự
# URL: 1 liên kết
# [153/493] Đang xử lý: 235.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [154/493] Đang xử lý: 236.html
# Nội dung: 10668 ký tự
# URL: 0 liên kết
# [155/493] Đang xử lý: 237.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [156/493] Đang xử lý: 238.html
# Nội dung: 4113 ký tự
# URL: 0 liên kết
# [157/493] Đang xử lý: 239.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
#
html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [206/493] Đang xử lý: 283.html
# Nội dung: 3461 ký tự
# URL: 0 liên kết
# [207/493] Đang xử lý: 284.html
# Nội dung: 13441 ký tự
# URL: 0 liên kết
# [208/493] Đang xử lý: 285.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [209/493] Đang xử lý: 286.html
# Nội dung: 9347 ký tự
# URL: 1 liên kết
# [210/493] Đang xử lý: 287.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [211/493] Đang xử lý: 288.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [212/493] Đang xử lý: 289.html
# Nội dung: 22542 ký tự
# URL: 0 liên kết
# [213/493] Đang xử lý: 29.html
# Nội dung: 13162 ký tự
# URL: 2 liên kết
# [214/493] Đang xử lý: 290.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [215/493] Đang xử lý: 291.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [216/493] Đang xử lý: 292.html
# Nội dung: 8179 ký tự
# URL: 1 liên kết
# [217/493] Đang xử lý: 293.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [218/493] Đang xử lý: 294.html
# Nội dung: 11343 ký tự
# URL: 1 liên kết
# [219/493] Đang xử lý: 295.html
# Nội dung: 14223 ký tự
# URL: 1 liên kết
# [220/493] Đang xử lý: 297.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [221/493] Đang xử lý: 298.html
# Nội dung: 12362 ký tự
# URL: 1 liên kết
# [222/493] Đang xử lý: 299.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [223/493] Đang xử lý: 3.html
# Nội dung: 12445 ký tự
# URL: 4 liên kết
# [224/493] Đang xử lý: 30.html
# Nội dung: 16918 ký tự
# URL: 2 liên kết
# [225/493] Đang xử lý: 300.html
# Nội dung: 8930 ký tự
# URL: 0 liên kết
# [226/493] Đang xử lý: 301.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [227/493] Đang xử lý: 303.html
# Nội dung: 11020 ký tự
# URL: 0 liên kết
# [228/493] Đang xử lý: 304.html
# Nội dung: 6369 ký tự
# URL: 1 liên kết
# [229/493] Đang xử lý: 305.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [230/493] Đang xử lý: 306.html
# Nội dung: 96 ký tự
# URL: 0 liên kết
# [231/493] Đang xử lý: 307.html
# Nội dung: 5605 ký tự
# URL: 0 liên kết
# [232/493] Đang xử lý: 308.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [233/493] Đang xử lý: 309.html
# Nội dung: 3917 ký tự
# URL: 0 liên kết
# [234/493] Đang xử lý: 31.html
# Nội dung: 18525 ký tự
# URL: 1 liên kết
# [235/493] Đang xử lý: 310.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [236/493] Đang xử lý: 311.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [237/493] Đang xử lý: 312.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [238/493] Đang xử lý: 313.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [239/493] Đang xử lý: 314.html
# Nội dung: 62 ký tự
# URL: 0 liên kết
# [240/493] Đang xử lý: 315.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [241/493] Đang xử lý: 316.html
# Nội dung: 11125 ký tự
# URL: 2 liên kết
# [242/493] Đang xử lý: 317.html
# Nội dung: 22190 ký tự
# URL: 0 liên kết
# [243/493] Đang xử lý: 318.html
# Nội dung: 14686 ký tự
# URL: 2 liên kết
# [244/493] Đang xử lý: 319.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [245/493] Đang xử lý: 32.html
# Nội dung: 14385 ký tự
# URL: 2 liên kết
# [246/493] Đang xử lý: 320.html
# Nội dung: 54 ký tự
# URL: 1 liên kết
# [247/493] Đang xử lý: 321.html
# Nội dung: 6716 ký tự
# URL: 2 liên kết
# [248/493] Đang xử lý: 322.html
# Nội dung: 5245 ký tự
# URL: 1 liên kết
# [249/493] Đang xử lý: 323.html
# Nội dung: 7046 ký tự
# URL: 1 liên kết
# [250/493] Đang xử lý: 324.html
# Nội dung: 8570 ký tự
# URL: 2 liên kết
# [251/493] Đang xử lý: 325.html
# Nội dung: 9614 ký tự
# URL: 0 liên kết
# [252/493] Đang xử lý: 326.html
# Nội dung: 8435 ký tự
# URL: 1 liên kết
# [253/493] Đang xử lý: 327.html
# Nội dung: 546 ký tự
# URL: 0 liên kết
# [254/493] Đang xử lý: 328.html
# Nội dung: 6438 ký tự
# URL: 1 liên kết
# [255/493] Đang xử lý: 329.html
# Nội dung: 1307 ký tự
# URL: 0 liên kết
# [256/493] Đang xử lý: 33.html
# Nội dung: 19217 ký tự
# URL: 1 liên kết
# [257/493] Đang xử lý: 330.html
# Nội dung: 4071 ký tự
# URL: 0 liên kết
# [258/493] Đang xử lý: 331.html
# Nội dung: 12918 ký tự
# URL: 1 liên kết
# [259/493] Đang xử lý: 332.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [260/493] Đang xử lý: 333.html
# Nội dung: 67 ký tự
# URL: 0 liên kết
# [261/493] Đang xử lý: 334.html
# Nội dung: 59 ký tự
# URL: 0 liên kết
# [262/493] Đang xử lý: 335.html
# Nội dung: 5528 ký tự
# URL: 1 liên kết
# [263/493] Đang xử lý: 336.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [264/493] Đang xử lý: 337.html
# Nội dung: 10058 ký tự
# URL: 0 liên kết
# [265/493] Đang xử lý: 338.html
# Nội dung: 6198 ký tự
# URL: 0 liên kết
# [266/493] Đang xử lý: 339.html
# Nội dung: 4117 ký tự
# URL: 0 liên kết
# [267/493] Đang xử lý: 34.html
# Nội dung: 13309 ký tự
# URL: 3 liên kết
# [268/493] Đang xử lý: 340.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [269/493] Đang xử lý: 341.html
# Nội dung: 11441 ký tự
# URL: 1 liên kết
# [270/493] Đang xử lý: 342.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [271/493] Đang xử lý: 343.html
# Nội dung: 11441 ký tự
# URL: 0 liên kết
# [272/493] Đang xử lý: 344.html
# Nội dung: 4606 ký tự
# URL: 0 liên kết
# [273/493] Đang xử lý: 345.html
# Nội dung: 8646 ký tự
# URL: 0 liên kết
# [274/493] Đang xử lý: 346.html
# Nội dung: 7980 ký tự
# URL: 0 liên kết
# [275/493] Đang xử lý: 347.html
# Nội dung: 8418 ký tự
# URL: 1 liên kết
# [276/493] Đang xử lý: 348.html
# Nội dung: 9402 ký tự
# URL: 2 liên kết
# [277/493] Đang xử lý: 349.html
# Nội dung: 65 ký tự
# URL: 1 liên kết
# [278/493] Đang xử lý: 35.html
# Nội dung: 6718 ký tự
# URL: 3 liên kết
# [279/493] Đang xử lý: 350.html
# Nội dung: 14794 ký tự
# URL: 1 liên kết
# [280/493] Đang xử lý: 351.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [281/493] Đang xử lý: 352.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [282/493] Đang xử lý: 353.html
# Nội dung: 12857 ký tự
# URL: 0 liên kết
# [283/493] Đang xử lý: 354.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [284/493] Đang xử lý: 355.html
# Nội dung: 5357 ký tự
# URL: 1 liên kết
# [285/493] Đang xử lý: 356.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
#
html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [322/493] Đang xử lý: 39.html
# Nội dung: 17497 ký tự
# URL: 2 liên kết
# [323/493] Đang xử lý: 390.html
# Nội dung: 52 ký tự
# URL: 0 liên kết
# [324/493] Đang xử lý: 391.html
# Nội dung: 12169 ký tự
# URL: 1 liên kết
# [325/493] Đang xử lý: 392.html
# Nội dung: 49 ký tự
# URL: 0 liên kết
# [326/493] Đang xử lý: 393.html
# Nội dung: 3905 ký tự
# URL: 0 liên kết
# [327/493] Đang xử lý: 394.html
# Nội dung: 9092 ký tự
# URL: 1 liên kết
# [328/493] Đang xử lý: 395.html
# Nội dung: 6584 ký tự
# URL: 0 liên kết
# [329/493] Đang xử lý: 396.html
# Nội dung: 4234 ký tự
# URL: 0 liên kết
# [330/493] Đang xử lý: 397.html
# Nội dung: 11819 ký tự
# URL: 1 liên kết
# [331/493] Đang xử lý: 398.html
# Nội dung: 14577 ký tự
# URL: 0 liên kết
# [332/493] Đang xử lý: 399.html
# Nội dung: 6552 ký tự
# URL: 0 liên kết
# [333/493] Đang xử lý: 4.html
# Nội dung: 17845 ký tự
# URL: 4 liên kết
# [334/493] Đang xử lý: 40.html
# Nội dung: 13990 ký tự
# URL: 2 liên kết
# [335/493] Đang xử lý: 400.html
# Nội dung: 10894 ký tự
# URL: 1 liên kết
# [336/493] Đang xử lý: 401.html
# Nội dung: 6020 ký tự
# URL: 0 liên kết
# [337/493] Đang xử lý: 402.html
# Nội dung: 0 ký tự
# URL: 0 liên kết
# [338/493] Đang xử lý: 403.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [339/493] Đang xử lý: 404.html
# Nội dung: 6533 ký tự
# URL: 1 liên kết
# [340/493] Đang xử lý: 405.html
# Nội dung: 65 ký tự
# URL: 1 liên kết
# [341/493] Đang xử lý: 406.html
# Nội dung: 5248 ký tự
# URL: 0 liên kết
# [342/493] Đang xử lý: 407.html
# Nội dung: 5955 ký tự
# URL: 0 liên kết
# [343/493] Đang xử lý: 408.html
# Nội dung: 3226 ký tự
# URL: 0 liên kết
# [344/493] Đang xử lý: 409.html
# Nội dung: 7612 ký tự
# URL: 0 liên kết
# [345/493] Đang xử lý: 41.html
# Nội dung: 17631 ký tự
# URL: 1 liên kết
# [346/493] Đang xử lý: 410.html
# Nội dung: 6457 ký tự
# URL: 1 liên kết
# [347/493] Đang xử lý: 411.html
# Nội dung: 8904 ký tự
# URL: 2 liên kết
# [348/493] Đang xử lý: 412.html
# Nội dung: 7014 ký tự
# URL: 1 liên kết
# [349/493] Đang xử lý: 413.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [350/493] Đang xử lý: 414.html
# Nội dung: 10856 ký tự
# URL: 0 liên kết
# [351/493] Đang xử lý: 415.html
# Nội dung: 11962 ký tự
# URL: 1 liên kết
# [352/493] Đang xử lý: 416.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [353/493] Đang xử lý: 417.html
# Nội dung: 1296 ký tự
# URL: 0 liên kết
# [354/493] Đang xử lý: 418.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [355/493] Đang xử lý: 419.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [356/493] Đang xử lý: 42.html
# Nội dung: 11923 ký tự
# URL: 1 liên kết
# [357/493] Đang xử lý: 420.html
# Nội dung: 2348 ký tự
# URL: 0 liên kết
# [358/493] Đang xử lý: 421.html
# Nội dung: 9180 ký tự
# URL: 0 liên kết
# [359/493] Đang xử lý: 422.html
# Nội dung: 11006 ký tự
# URL: 0 liên kết
# [360/493] Đang xử lý: 423.html
# Nội dung: 2765 ký tự
# URL: 0 liên kết
# [361/493] Đang xử lý: 424.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [362/493] Đang xử lý: 425.html
# Nội dung: 35 ký tự
# URL: 0 liên kết
# [363/493] Đang xử lý: 426.html
# Nội dung: 13835 ký tự
# URL: 0 liên kết
# [364/493] Đang xử lý: 427.html
# Nội dung: 56 ký tự
# URL: 1 liên kết
# [365/493] Đang xử lý: 428.html
# Nội dung: 8237 ký tự
# URL: 1 liên kết
# [366/493] Đang xử lý: 429.html
# Nội dung: 1291 ký tự
# URL: 0 liên kết
# [367/493] Đang xử lý: 43.html
# Nội dung: 12791 ký tự
# URL: 1 liên kết
# [368/493] Đang xử lý: 430.html
# Nội dung: 10434 ký tự
# URL: 0 liên kết
# [369/493] Đang xử lý: 431.html
# Nội dung: 8106 ký tự
# URL: 1 liên kết
# [370/493] Đang xử lý: 432.html
# Nội dung: 11655 ký tự
# URL: 1 liên kết
# [371/493] Đang xử lý: 433.html
# Nội dung: 10657 ký tự
# URL: 2 liên kết
# [372/493] Đang xử lý: 434.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [373/493] Đang xử lý: 435.html
# Nội dung: 10938 ký tự
# URL: 0 liên kết
# [374/493] Đang xử lý: 436.html
# Nội dung: 6885 ký tự
# URL: 0 liên kết
# [375/493] Đang xử lý: 437.html
# Nội dung: 18368 ký tự
# URL: 1 liên kết
# [376/493] Đang xử lý: 438.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [377/493] Đang xử lý: 439.html
# Nội dung: 10023 ký tự
# URL: 0 liên kết
# [378/493] Đang xử lý: 44.html
# Nội dung: 10626 ký tự
# URL: 2 liên kết
# [379/493] Đang xử lý: 440.html
# Nội dung: 13122 ký tự
# URL: 0 liên kết
# [380/493] Đang xử lý: 441.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [381/493] Đang xử lý: 442.html
# Nội dung: 3818 ký tự
# URL: 0 liên kết
# [382/493] Đang xử lý: 443.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [383/493] Đang xử lý: 444.html
# Nội dung: 12040 ký tự
# URL: 0 liên kết
# [384/493] Đang xử lý: 445.html
# Nội dung: 68 ký tự
# URL: 1 liên kết
# [385/493] Đang xử lý: 447.html
# Nội dung: 10579 ký tự
# URL: 0 liên kết
# [386/493] Đang xử lý: 448.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [387/493] Đang xử lý: 449.html
# Nội dung: 9750 ký tự
# URL: 2 liên kết
# [388/493] Đang xử lý: 45.html
# Nội dung: 18860 ký tự
# URL: 1 liên kết
# [389/493] Đang xử lý: 450.html
# Nội dung: 10397 ký tự
# URL: 1 liên kết
# [390/493] Đang xử lý: 451.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [391/493] Đang xử lý: 452.html
# Nội dung: 5279 ký tự
# URL: 0 liên kết
# [392/493] Đang xử lý: 453.html
# Nội dung: 1311 ký tự
# URL: 0 liên kết
# [393/493] Đang xử lý: 454.html
# Nội dung: 4138 ký tự
# URL: 1 liên kết
# [394/493] Đang xử lý: 455.html
# Nội dung: 3377 ký tự
# URL: 0 liên kết
# [395/493] Đang xử lý: 456.html
# Nội dung: 8356 ký tự
# URL: 0 liên kết
# [396/493] Đang xử lý: 457.html
# Nội dung: 11576 ký tự
# URL: 1 liên kết
# [397/493] Đang xử lý: 458.html
# Nội dung: 1291 ký tự
# URL: 0 liên kết
# [398/493] Đang xử lý: 459.html
# Nội dung: 7795 ký tự
# URL: 0 liên kết
# [399/493] Đang xử lý: 46.html
# Nội dung: 12824 ký tự
# URL: 2 liên kết
# [400/493] Đang xử lý: 460.html
# Nội dung: 5914 ký tự
# URL: 0 liên kết
# [401/493] Đang xử lý: 461.html
# Nội dung: 9836 ký tự
# URL: 0 liên kết
# [402/493] Đang xử lý: 462.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [403/493] Đang xử lý: 463.html
# Nội dung: 7667 ký tự
# URL: 0 liên kết
# [404/493] Đang xử lý: 464.html
# Nội dung: 64 ký tự
# URL: 1 liên kết
# [405/493] Đang xử lý: 465.html
# Nội dung: 10523 ký tự
# URL: 0 liên kết
# [406/493] Đang xử lý: 466.html
# Nội dung: 8442 ký tự
# URL: 0 liên kết
# [407/493] Đang xử lý: 467.html
# Nội dung: 11559 ký tự
# URL: 0 liên kết
# [408/493] Đang xử lý: 468.html
# Nội dung: 13789 ký tự
# URL: 1 liên kết
# [409/493] Đang xử lý: 469.html
# Nội dung: 8862 ký tự
# URL: 0 liên kết
# [410/493] Đang xử lý: 47.html
# Nội dung: 13179 ký tự
# URL: 2 liên kết
# [411/493] Đang xử lý: 470.html
# Nội dung: 6361 ký tự
# URL: 0 liên kết
# [412/493] Đang xử lý: 471.html
# Nội dung: 10973 ký tự
# URL: 1 liên kết
# [413/493] Đang xử lý: 472.html
# Nội dung: 8176 ký tự
# URL: 0 liên kết
# [414/493] Đang xử lý: 473.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [415/493] Đang xử lý: 474.html
# Nội dung: 14368 ký tự
# URL: 0 liên kết
# [416/493] Đang xử lý: 475.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [417/493] Đang xử lý: 476.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [418/493] Đang xử lý: 477.html
# Nội dung: 101 ký tự
# URL: 0 liên kết
# [419/493] Đang xử lý: 478.html
# Nội dung: 7576 ký tự
# URL: 0 liên kết
# [420/493] Đang xử lý: 479.html
# Nội dung: 10396 ký tự
# URL: 0 liên kết
# [421/493] Đang xử lý: 48.html
# Nội dung: 15528 ký tự
# URL: 2 liên kết
# [422/493] Đang xử lý: 480.html
# Nội dung: 15853 ký tự
# URL: 2 liên kết
# [423/493] Đang xử lý: 481.html
# Nội dung: 4979 ký tự
# URL: 0 liên kết
# [424/493] Đang xử lý: 482.html
# Nội dung: 11303 ký tự
# URL: 0 liên kết
# [425/493] Đang xử lý: 483.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [426/493] Đang xử lý: 484.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [427/493] Đang xử lý: 485.html
# Nội dung: 12966 ký tự
# URL: 0 liên kết
# [428/493] Đang xử lý: 486.html
# Nội dung: 9293 ký tự
# URL: 0 liên kết
# [429/493] Đang xử lý: 487.html
# Nội dung: 8690 ký tự
# URL: 1 liên kết
# [430/493] Đang xử lý: 488.html
# Nội dung: 14947 ký tự
# URL: 0 liên kết
# [431/493] Đang xử lý: 489.html
# Nội dung: 10739 ký tự
# URL: 0 liên kết
# [432/493] Đang xử lý: 49.html
# Nội dung: 21118 ký tự
# URL: 2 liên kết
# [433/493] Đang xử lý: 490.html
# Nội dung: 9712 ký tự
# URL: 0 liên kết
# [434/493] Đang xử lý: 491.html
# Nội dung: 103 ký tự
# URL: 0 liên kết
# [435/493] Đang xử lý: 492.html
# Nội dung: 3598 ký tự
# URL: 0 liên kết
# [436/493] Đang xử lý: 493.html
# Nội dung: 8580 ký tự
# URL: 0 liên kết
# [437/493] Đang xử lý: 494.html
# Nội dung: 8372 ký tự
# URL: 0 liên kết
# [438/493] Đang xử lý: 495.html
# Nội dung: 3671 ký tự
# URL: 0 liên kết
# [439/493] Đang xử lý: 5.html
# Nội dung: 18769 ký tự
# URL: 1 liên kết
# [440/493] Đang xử lý: 50.html
# Nội dung: 16825 ký tự
# URL: 2 liên kết
# [441/493] Đang xử lý: 51.html
# Nội dung: 15671 ký tự
# URL: 2 liên kết
# [442/493] Đang xử lý: 52.html
# Nội dung: 15029 ký tự
# URL: 3 liên kết
# [443/493] Đang xử lý: 53.html
# Nội dung: 2636 ký tự
# URL: 0 liên kết
# [444/493] Đang xử lý: 54.html
# Nội dung: 3955 ký tự
# URL: 0 liên kết
# [445/493] Đang xử lý: 55.html
# Nội dung: 16518 ký tự
# URL: 4 liên kết
# [446/493] Đang xử lý: 56.html
# Nội dung: 14288 ký tự
# URL: 2 liên kết
# [447/493] Đang xử lý: 57.html
# Nội dung: 11760 ký tự
# URL: 2 liên kết
# [448/493] Đang xử lý: 58.html
# Nội dung: 5995 ký tự
# URL: 3 liên kết
# [449/493] Đang xử lý: 59.html
# Nội dung: 5995 ký tự
# URL: 3 liên kết
# [450/493] Đang xử lý: 6.html
# Nội dung: 15666 ký tự
# URL: 1 liên kết
# [451/493] Đang xử lý: 60.html
# Nội dung: 13288 ký tự
# URL: 1 liên kết
# [452/493] Đang xử lý: 61.html
# Nội dung: 11524 ký tự
# URL: 1 liên kết
# [453/493] Đang xử lý: 62.html
# Nội dung: 14325 ký tự
# URL: 2 liên kết
# [454/493] Đang xử lý: 63.html
# Nội dung: 17270 ký tự
# URL: 1 liên kết
# [455/493] Đang xử lý: 64.html
# Nội dung: 9829 ký tự
# URL: 2 liên kết
# [456/493] Đang xử lý: 65.html
# Nội dung: 11537 ký tự
# URL: 1 liên kết
# [457/493] Đang xử lý: 66.html
# Nội dung: 8360 ký tự
# URL: 3 liên kết
# [458/493] Đang xử lý: 67.html
# Nội dung: 9952 ký tự
# URL: 2 liên kết
# [459/493] Đang xử lý: 68.html
# Nội dung: 9992 ký tự
# URL: 2 liên kết
# [460/493] Đang xử lý: 69.html
# Nội dung: 5659 ký tự
# URL: 2 liên kết
# [461/493] Đang xử lý: 7.html
# Nội dung: 11327 ký tự
# URL: 2 liên kết
# [462/493] Đang xử lý: 70.html
# Nội dung: 12557 ký tự
# URL: 3 liên kết
# [463/493] Đang xử lý: 71.html
# Nội dung: 13650 ký tự
# URL: 3 liên kết
# [464/493] Đang xử lý: 72.html
# Nội dung: 12639 ký tự
# URL: 2 liên kết
# [465/493] Đang xử lý: 73.html
# Nội dung: 10341 ký tự
# URL: 2 liên kết
# [466/493] Đang xử lý: 74.html
# Nội dung: 6124 ký tự
# URL: 3 liên kết
# [467/493] Đang xử lý: 75.html
# Nội dung: 13734 ký tự
# URL: 1 liên kết
# [468/493] Đang xử lý: 76.html
# Nội dung: 15199 ký tự
# URL: 2 liên kết
# [469/493] Đang xử lý: 77.html
# Nội dung: 11166 ký tự
# URL: 1 liên kết
# [470/493] Đang xử lý: 78.html
# Nội dung: 12210 ký tự
# URL: 3 liên kết
# [471/493] Đang xử lý: 79.html
# Nội dung: 13554 ký tự
# URL: 2 liên kết
# [472/493] Đang xử lý: 8.html
# Nội dung: 11512 ký tự
# URL: 1 liên kết
# [473/493] Đang xử lý: 80.html
# Nội dung: 2155 ký tự
# URL: 0 liên kết
# [474/493] Đang xử lý: 81.html
# Nội dung: 11460 ký tự
# URL: 2 liên kết
# [475/493] Đang xử lý: 82.html
# Nội dung: 10667 ký tự
# URL: 2 liên kết
# [476/493] Đang xử lý: 83.html
# Nội dung: 10096 ký tự
# URL: 3 liên kết
# [477/493] Đang xử lý: 84.html
# Nội dung: 18330 ký tự
# URL: 1 liên kết
# [478/493] Đang xử lý: 85.html
# Nội dung: 10328 ký tự
# URL: 2 liên kết
# [479/493] Đang xử lý: 86.html
# Nội dung: 9395 ký tự
# URL: 2 liên kết
# [480/493] Đang xử lý: 87.html
# Nội dung: 20603 ký tự
# URL: 1 liên kết
# [481/493] Đang xử lý: 88.html
# Nội dung: 11895 ký tự
# URL: 1 liên kết
# [482/493] Đang xử lý: 89.html
# Nội dung: 31828 ký tự
# URL: 1 liên kết
# [483/493] Đang xử lý: 9.html
# Nội dung: 21807 ký tự
# URL: 4 liên kết
# [484/493] Đang xử lý: 90.html
# Nội dung: 16255 ký tự
# URL: 2 liên kết
# [485/493] Đang xử lý: 91.html
# Nội dung: 17850 ký tự
# URL: 2 liên kết
# [486/493] Đang xử lý: 92.html
# Nội dung: 23272 ký tự
# URL: 1 liên kết
# [487/493] Đang xử lý: 93.html
# Nội dung: 27096 ký tự
# URL: 5 liên kết
# [488/493] Đang xử lý: 94.html
# Nội dung: 8877 ký tự
# URL: 3 liên kết
# [489/493] Đang xử lý: 95.html
# Nội dung: 15614 ký tự
# URL: 3 liên kết
# [490/493] Đang xử lý: 96.html
# Nội dung: 14118 ký tự
# URL: 1 liên kết
# [491/493] Đang xử lý: 97.html
# Nội dung: 12409 ký tự
# URL: 6 liên kết
# [492/493] Đang xử lý: 98.html
# Nội dung: 11350 ký tự
# URL: 2 liên kết
# [493/493] Đang xử lý: 99.html
# Nội dung: 8783 ký tự
# URL: 2 liên kết
#
# Đã lưu 336 URL vào: extracted_urls.csv

# %%
# BÁO CÁO KẾT QUẢ
def generate_report(results):
    success_count = sum(1 for r in results if r['success'])
    total_urls = sum(len(r['urls']) for r in results)
    total_clean_chars = sum(r['clean_length'] for r in results)
    
    print("\n" + "=" * 60)
    print("BÁO CÁO KẾT QUẢ XỬ LÝ")
    print("=" * 60)
    print(f"Tổng số file HTML: {len(results)}")
    print(f"File xử lý thành công: {success_count}")
    print(f"File thất bại: {len(results) - success_count}")
    print(f"Tổng số URL trích xuất: {total_urls}")
    print(f"Tổng ký tự văn bản sạch: {total_clean_chars:,}")
    
    # Hiển thị chi tiết 5 file đầu
    print(f"\nCHI TIẾT 5 FILE ĐẦU:")
    print("-" * 50)
    for i, result in enumerate(results[:5]):
        status = "success" if result['success'] else "fail"
        print(f"{status} {result['title'][:50]}...")
        print(f"Ký tự: {result['clean_length']} | URL: {len(result['urls'])}")

generate_report(results)
# Out:
# ============================================================
# BÁO CÁO KẾT QUẢ XỬ LÝ
# ============================================================
# Tổng số file HTML: 493
# File xử lý thành công: 399
# File thất bại: 94
# Tổng số URL trích xuất: 336
# Tổng ký tự văn bản sạch: 3,292,323
#
# CHI TIẾT 5 FILE ĐẦU:
# --------------------------------------------------
# success Cẩm nang du lịch An Giang 2024: 12 địa điểm vui ch...
# Ký tự: 9722 | URL: 1
# success Cẩm nang Du lịch Bà Nà Hills 2025 từ A-Z: Di chuyể...
# Ký tự: 14313 | URL: 2
# success Cẩm nang Du lịch BÌNH LIÊU 2025 từ A-Z: lưu trú, ă...
# Ký tự: 9866 | URL: 2
# success Kinh nghiệm du lịch Sa Pa 2025 từ A-Z: di chuyển, ...
# Ký tự: 13143 | URL: 1
# success Cẩm nang Du lịch Trà Vinh 2025 từ A-Z: Di chuyển, ...
# Ký tự: 16374 | URL: 1

# %%
# KIỂM TRA KẾT QUẢ
def verify_results():
    
    txt_files = [f for f in os.listdir(OUTPUT_FOLDER) if f.endswith('.txt')]
    
    print(f"\nKIỂM TRA KẾT QUẢ:")
    print(f"Số file TXT đã tạo: {len(txt_files)}")
    
    # Kiểm tra 3 file đầu
    for txt_file in txt_files[:3]:
        file_path = os.path.join(OUTPUT_FOLDER, txt_file)
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
        
        print(f"\n{txt_file}:")
        print(f"Độ dài: {len(content)} ký tự")
        print(f"Nội dung: {content[:100]}...")

verify_results()
# Out:
# KIỂM TRA KẾT QUẢ:
# Số file TXT đã tạo: 399
#
# 0.txt:
# Độ dài: 9722 ký tự
# Nội dung: Cẩm nang du lịch An Giang 2024: 12 địa điểm vui chơi phải trải nghiệm An Giang 3 Trở lại Du lịch Điề...
#
# 1.txt:
# Độ dài: 14313 ký tự
# Nội dung: Cẩm nang Du lịch Bà Nà Hills 2025 từ A-Z: Di chuyển, ăn chơi, thăm quan, đặc sản... mới nhất Khu du ...
#
# 10.txt:
# Độ dài: 9866 ký tự
# Nội dung: Cẩm nang Du lịch BÌNH LIÊU 2025 từ A-Z: lưu trú, ăn chơi, đặc sản... mới nhất Bình Liêu 3 Trở lại Du...
