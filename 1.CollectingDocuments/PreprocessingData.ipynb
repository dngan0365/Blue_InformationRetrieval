# %% [markdown]
# # Tien xu ly Du lieu

# %%
import os
import re
import csv
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin, urlparse
import requests

# %%
# Cấu hình đường dẫn
INPUT_FOLDER = "data"  
OUTPUT_FOLDER = "data_clean"  
URLS_CSV = "extracted_urls.csv"  

# Tạo thư mục output nếu chưa tồn tại
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %% [markdown]
# ## Chuan hoa du lieu

# %%
import re

def normalize_text(text):
    if not text:
        return ""
    
    # 1. Chuyển đổi các thực thể HTML còn sót lại (nếu có)
    # Ví dụ: &nbsp; -> khoảng trắng, &lt; -> <
    import html
    text = html.unescape(text)
    
    # 2. Chuẩn hóa khoảng trắng (giữ lại 1 dấu cách duy nhất)
    text = re.sub(r'\s+', ' ', text)
    
    # 3. Sửa lỗi dấu câu (Rất tốt cho việc đọc hiểu của AI/NLP)
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)
    text = re.sub(r'([.,!?;:])(?=[^\s])', r'\1 ', text) # Chỉ thêm cách nếu sau đó không phải khoảng trắng
    
    # 4. THAY THẾ dòng loại bỏ ký tự đặc biệt bằng cách lọc chọn lọc hơn
    # Thay vì xóa hết, chỉ xóa các ký tự "rác" không thể đọc được (control characters)
    # Giữ lại các ký tự phổ biến trong văn bản kỹ thuật: @, #, $, %, &, *, /, +, =, [, ], {, }
    text = "".join(ch for ch in text if ch.isprintable())

    # 5. Xử lý dấu gạch ngang (thường bị dính chữ khi trích xuất từ HTML)
    text = re.sub(r'(\w)-(\w)', r'\1 - \2', text) # Tùy chọn: giúp tách từ nếu là liệt kê
    
    return text.strip()

# %% [markdown]
# ## Thu thap cac url co trong website de tinh do lien ket

# %%
# 1. Đọc file CSV
csv_file = "info.csv"
df = pd.read_csv(csv_file)
df
# Out:
#       id                                                url  \
# 0      0  https://vnexpress.net/cam-nang-du-lich-an-gian...
# 1      1  https://vnexpress.net/cam-nang-du-lich-ba-na-h...
# 2      2  https://vnexpress.net/cam-nang-du-lich-bac-gia...
# 3      3  https://vnexpress.net/cam-nang-du-lich-binh-th...
# 4      4  https://vnexpress.net/cam-nang-du-lich-binh-di...
# ..   ...                                                ...
# 489  491  https://vinwonders.com/vi/wonderpedia/news/tha...
# 490  492  https://www.ivivu.com/blog/2023/05/kham-pha-th...
# 491  493  https://mia.vn/cam-nang-du-lich/kham-pha-mai-c...
# 492  494  https://mia.vn/cam-nang-du-lich/kham-pha-nha-t...
# 493  495  https://www.ivivu.com/blog/2024/10/nha-tho-go-...
#
#                                                  title
# 0                            Cẩm nang du lịch An Giang
# 1                         Cẩm nang du lịch Bà Nà Hills
# 2                           Cẩm nang du lịch Bắc Giang
# 3                          Cẩm nang du lịch Bình Thuận
# 4                           Cẩm nang du lịch Bình Định
# ..                                                 ...
# 489  Tháp Nhạn Phú Yên có gì? Kinh nghiệm tham quan...
# 490  Khám phá thung lũng Mai Châu đẹp lãng mạn tại ...
# 491       Khám phá Mai Châu Hòa Bình có gì cùng MIA.vn
# 492  Khám phá Nhà thờ gỗ Kon Tum với tuổi đời hơn 1...
# 493  Nhà thờ gỗ Kontum hơn trăm tuổi cổ kính uy nghiêm
#
# [494 rows x 3 columns]

# %% [markdown]
# Lay base_url trong file info.csv

# %%
# Tạo dict id -> url
id_to_url = dict(zip(df['id'], df['url']))

# 2. Lấy base_url từ CSV
def get_base_url(file_id):
    """
    Lấy domain gốc từ URL tương ứng trong CSV
    ví dụ: https://vnexpress.net/cam-nang-du-lich-an-giang-4445399.html -> https://vnexpress.net
    """
    url = id_to_url.get(file_id)
    if url:
        parsed = urlparse(url)
        return f"{parsed.scheme}://{parsed.netloc}"
    return None

# %%
# Tạo set các URL trong CSV để lọc
valid_urls = set(df['url'].tolist())

# %%
from urllib.parse import urlparse, urljoin

# 2. Hàm kiểm tra URL hợp lệ
def is_valid_url(url):
    try:
        parsed = urlparse(url)
        return bool(parsed.netloc) and bool(parsed.scheme)
    except:
        return False

# %% [markdown]
# ## Lay cac thong tin quan trong

# %%
import os
from bs4 import BeautifulSoup

def extract_main_content(soup):
    # 1. Danh sách các thẻ "rác" thường chứa nội dung không liên quan
    unwanted_tags = [
        'nav', 'footer', 'header', 'aside', 'script', 'style', 
        'noscript', 'form', 'svg', 'iframe', 'button', 'ads'
    ]
    
    # 2. Loại bỏ các thẻ rác khỏi đối tượng soup
    for tag in soup.find_all(unwanted_tags):
        tag.decompose()

    # 3. Loại bỏ các thành phần dựa trên class hoặc id phổ biến của quảng cáo/menu
    # Bạn có thể thêm các từ khóa thường gặp ở đây
    for div in soup.find_all('div', class_=['sidebar', 'menu', 'footer', 'nav', 'advertisement', 'social-share']):
        div.decompose()

    # 4. Xác định các thẻ chứa văn bản thực sự
    content_tags = [
        'h1', 'h2', 'h3', 'h4', 'h5', 'h6',
        'p', 'li', 'blockquote', 'pre', 'code',
        'td', 'th', 'caption', 'figcaption'
    ]

    all_content = []
    
    # 5. Duyệt và lấy văn bản
    for elem in soup.find_all(content_tags):
        # Kiểm tra xem thẻ này có nằm trong một thẻ rác nào khác không (đề phòng)
        text = elem.get_text(separator=' ', strip=True)

        # Lọc bỏ các đoạn text quá ngắn hoặc mang tính chất điều hướng (Ví dụ: "Xem thêm", "Chia sẻ")
        if len(text) > 20:  # Tăng ngưỡng lên một chút để lọc tốt hơn
            all_content.append(text)

    return '. '.join(all_content)

# %%
def extract_main_content(soup):
    all_content = []

    content_tags = [
        'h1','h2','h3','h4','h5','h6',
        'p','li','blockquote',
        'pre','code',
        'td','th','caption','figcaption'
    ]

    for elem in soup.find_all(content_tags):
        text = elem.get_text(separator=' ', strip=True)

        # ⚠️ FILTER THẬT SỰ
        if len(text) >= 10:
            all_content.append(text)

    return '\n\n'.join(all_content)

# %% [markdown]
# Test 1 file html

# %%
html_file_path = 'data/170.html'

with open(html_file_path, 'r', encoding='utf-8', errors='ignore') as file:
    html_content = file.read()

soup = BeautifulSoup(html_content, 'html.parser')

# Lấy nội dung đã làm sạch
clean_text = extract_main_content(soup)

print(f"Tiêu đề: {soup.title.string if soup.title else 'No Title'}")
print("-" * 30)
print(clean_text)
# Out:
# Tiêu đề: Hồ Xạ Hương – Wikipedia tiếng Việt
# ------------------------------
# Trang Chính
#
# Nội dung chọn lọc
#
# Bài viết ngẫu nhiên
#
# Thay đổi gần đây
#
# Báo lỗi nội dung
#
# Giới thiệu Wikipedia
#
# Thảo luận chung
#
# Giúp sử dụng
#
# Tải lên tập tin
#
# Nhỏ Tiêu chuẩn Lớn
#
# Tiêu chuẩn Rộng
#
# Tự động Sáng Tối
#
# Tạo tài khoản
#
# Tạo tài khoản
#
# Biểu quyết xóa Xóa bài : Tấn Thi • Jimmy Nhựt Hà • Đường cao tốc Cà Mau – Đất Mũi • A Páo • Thề không phản bội quê hương • Như một huyền thoại (lần 2) • Tấn Tùng (lần 3) • Miss Cosmo • Gia đình số đỏ • Tân Quảng • Xóa tập tin (1) • Phục hồi bài : Bảo Định (diễn viên)
#
# 1 Quan cảnh
#
# 2 Chú thích
#
# 3 Tham khảo
#
# Hồ Xạ Hương
#
# Sửa mã nguồn
#
# Xem lịch sử
#
# Sửa mã nguồn
#
# Xem lịch sử
#
# Tự động [F9]
#
# Bỏ dấu kiểu cũ [F7]
#
# Đúng chính tả [F8]
#
# Các liên kết đến đây
#
# Thay đổi liên quan
#
# Liên kết thường trực
#
# Thông tin trang
#
# Trích dẫn trang này
#
# Tạo URL rút gọn
#
# Sửa liên kết giữa ngôn ngữ
#
# Tạo một quyển sách
#
# Tải dưới dạng PDF
#
# Bản để in ra
#
# Khoản mục Wikidata
#
# Bài viết này cần thêm chú thích nguồn gốc để kiểm chứng thông tin . Mời bạn giúp hoàn thiện bài viết này bằng cách bổ sung chú thích tới các nguồn đáng tin cậy . Các nội dung không có nguồn có thể bị nghi ngờ và xóa bỏ. ( Tìm hiểu cách thức và thời điểm xóa thông báo này )
#
# Hồ Xạ Hương là một hồ nước ngọt , nhân tạo toạ lạc tại xã Minh Quang , huyện Tam Đảo , Vĩnh Phúc . Đây là một hồ nước khá sâu, rộng khoảng 83 ha, với nhiều ngách lớn xuyên qua các cánh rừng, được xây dựng năm 1984 với sức chứa hơn 12 triệu m3 nước, đủ nước tưới quanh năm cho 1.850 ha đồng ruộng của ba huyện Tam Đảo , Bình Xuyên và Tam Dương .
#
# Cảnh quan nơi đây cũng đa dạng cả về địa hình và địa chất . Các đồi đất đan xen các ngọn núi đá . Trong vùng đa phần là núi đá hoa cương và đá thạch anh màu xanh xám. Tuy không có sự xâm thực của phong thủy để tạo ra những hang động kỳ bí như ở vùng núi đá vôi , núi đá nơi đây lại có nhiều vết nứt lớn nhỏ để tạo nên nhiều khe hẻm, nhiều mái đá lõm sâu làm nơi trú ngụ cho muông thú.
#
# Theo ý đồ của người thiết kế ban đầu, dù mực nước hồ hạ xuống tới "cốt chết" không tự chảy ra mương được nữa thì trong lòng hồ vẫn còn 700.000m3 nước dự trữ, nhiều chỗ có độ sâu tới 03m nước. Nghĩa là hồ Xạ Hương không bao giờ khô cạn trơ ra đáy bùn làm ảnh hường tới môi trường sinh thái và cảnh quan xung quanh. Trên bờ hồ hoàn toàn không có nhà dân.
#
# Hồ Xạ Hương Lưu trữ ngày 4 tháng 3 năm 2016 tại Wayback Machine
#
# Bài viết tỉnh Phú Thọ , Việt Nam này vẫn còn sơ khai . Bạn có thể giúp Wikipedia mở rộng nội dung để bài được hoàn chỉnh hơn.
#
# Bài viết tỉnh Phú Thọ , Việt Nam này vẫn còn sơ khai . Bạn có thể giúp Wikipedia mở rộng nội dung để bài được hoàn chỉnh hơn.
#
# Sơ khai Phú Thọ
#
# Tam Đảo (huyện)
#
# Hồ tại Vĩnh Phúc
#
# Trang thiếu chú thích trong bài
#
# Bản mẫu webarchive dùng liên kết wayback
#
# Tất cả bài viết sơ khai
#
# Trang này được sửa đổi lần cuối vào ngày 11 tháng 11 năm 2025, 09:41.
#
# Văn bản được phát hành theo Giấy phép Creative Commons Ghi công–Chia sẻ tương tự ; có thể áp dụng điều khoản bổ sung. Với việc sử dụng trang web này, bạn chấp nhận Điều khoản Sử dụng và Quy định quyền riêng tư . Wikipedia® là thương hiệu đã đăng ký của Wikimedia Foundation, Inc. , một tổ chức phi lợi nhuận.
#
# Chính sách quyền riêng tư
#
# Giới thiệu Wikipedia
#
# Lời phủ nhận
#
# Bộ Quy tắc Ứng xử Chung
#
# Lập trình viên
#
# Tuyên bố về cookie
#
# Phiên bản di động
#
# Thiết lập tính năng xem trước

# %%
id_to_url = {}
url_to_id = {}

with open('info.csv', newline='', encoding='utf-8') as f:
    reader = csv.DictReader(f)
    for row in reader:
        file_id = int(row['id'])
        url = row['url']

        id_to_url[file_id] = url
        url_to_id[url] = file_id

# %%
from urllib.parse import urlparse

def get_base_url_by_id(file_id, id_to_url):
    url = id_to_url.get(file_id)
    if not url:
        return None

    parsed = urlparse(url)
    return f"{parsed.scheme}://{parsed.netloc}"

# %%
print(get_base_url_by_id(170, id_to_url))
# https://vi.wikipedia.org

print(get_base_url_by_id(175, id_to_url))
# https://vnexpress.net
# Out:
# https://vi.wikipedia.org
# https://vi.wikipedia.org

# %%
from urllib.parse import urljoin, urlparse

def extract_related_urls(soup, base_url, valid_urls):
    """
    Trích xuất các URL từ thẻ <a> trong HTML,
    chuẩn hóa về URL đầy đủ và chỉ giữ URL nằm trong valid_urls
    """

    related_urls = set()

    if not base_url:
        return []

    for a in soup.find_all('a', href=True):
        href = a['href'].strip()

        # Debug nếu cần
        # print("Found href:", href)

        # Bỏ link rác
        if href.startswith(('javascript:', 'mailto:', 'tel:', '#')) or len(href) < 5:
            continue

        # 🔥 Nếu đã là URL đầy đủ
        if href.startswith(('http://', 'https://')):
            full_url = href
        else:
            # 🔥 URL tương đối → join với base_url
            full_url = urljoin(base_url, href)

        # Kiểm tra hợp lệ & có trong CSV
        parsed = urlparse(full_url)
        if parsed.scheme and parsed.netloc and full_url in valid_urls:
            related_urls.add(full_url)

    return list(related_urls)

# %%
file_id = 1
html_file_path = f'data/{file_id}.html'

with open(html_file_path, 'r', encoding='utf-8', errors='ignore') as f:
    html_content = f.read()

soup = BeautifulSoup(html_content, 'html.parser')

base_url = get_base_url_by_id(file_id, id_to_url)
print("Base URL:", base_url)

related_urls = extract_related_urls(
    soup,
    base_url,
    id_to_url.values()
)
# Out:
# Base URL: https://vnexpress.net

# %%
related_urls
# Out:
# ['https://vnexpress.net/cam-nang-du-lich-ba-na-hills-4866205.html',
#  'https://vnexpress.net/cam-nang-du-lich-da-nang-4470111.html']

# %% [markdown]
# ## Xu lay 1 file html

# %%
# HÀM XỬ LÝ FILE HTML CHÍNH
import os
from bs4 import BeautifulSoup

def process_html_file(html_file_path, base_url=None, valid_urls=None, file_id=None):
    """
    Xử lý 1 file HTML:
    - Lọc quảng cáo/rác
    - Lấy text chính
    - Chuẩn hóa text
    - Trích xuất URL liên quan (chỉ những URL có trong valid_urls)
    
    Args:
        html_file_path: đường dẫn file HTML
        base_url: domain gốc để chuẩn hóa URL
        valid_urls: danh sách URL hợp lệ để lọc
        file_id: ID file, để gắn metadata
    """
    try:
        # Đọc file HTML
        with open(html_file_path, 'r', encoding='utf-8', errors='ignore') as file:
            html_content = file.read()
        
        soup = BeautifulSoup(html_content, 'html.parser')

        # Lấy tiêu đề trang
        title = soup.title.string if soup.title else os.path.basename(html_file_path)
        
        # Lọc và lấy nội dung chính
        clean_text = extract_main_content(soup)
        
        if clean_text and len(clean_text) > 0:
            clean_text = normalize_text(clean_text)

            # Trích xuất URL liên quan, chỉ những URL hợp lệ
            base_url = get_base_url_by_id(file_id, id_to_url)
            print("Base URL:", base_url)

            related_urls = extract_related_urls(
                soup,
                base_url,
                id_to_url.values()
            )
            return {
                'file_id': file_id,
                'title': title,
                'clean_text': clean_text,
                'urls': related_urls,
                'clean_length': len(clean_text),
                'success': True,
            }
        else:
            return {
                'file_id': file_id,
                'title': title,
                'clean_text': "",
                'urls': [],
                'clean_length': 0,
                'success': False,
            }
            
    except Exception as e:
        print(f"Lỗi xử lý {html_file_path}: {str(e)}")
        return {
            'file_id': file_id,
            'title': os.path.basename(html_file_path),
            'clean_text': "",
            'urls': [],
            'clean_length': 0,
            'success': False,
        }

# %%
# 3. Ví dụ sử dụng với process_html_file
file_id = 0
html_file_path = f"./data/{file_id}.html"
base_url = get_base_url(file_id)

result = process_html_file(
    html_file_path,
    base_url=base_url,
    valid_urls=set(df['url'].tolist()),
    file_id=file_id
)

print(result.get('clean_text', ''))
# Out:
# Base URL: https://vnexpress.net
# Thông báo Ý kiến Tin đã xem Bật nhận thông báo Đang tải dữ liệu. . . Trở lại Du lịch Điều hướng nhanh An Giang mùa nào đẹp? Khách sạn, homestay Đặc sản An Giang Mua gì làm quà An Giang là tỉnh ở miền Tây Nam Bộ, một phần trong vùng tứ giác Long Xuyên. Tỉnh thuộc vùng đồng bằng sông Cửu Long, có sông Tiền và sông Hậu chảy qua. Đường biên giới dài gần 100 km giáp Campuchia. An Giang mùa nào đẹp? Từ tháng 3 đến tháng 5, An Giang trong mùa nắng khô ráo. Nếu muốn ngắm thảm bèo cũng như thế giới tự nhiên xanh mát ở rừng tràm Trà Sư vào mù
c tại khóm Xuân Phú, thị trấn Tịnh Biên, huyện Tịnh Biên, ngôi chùa có kiến trúc Á Đông được xây thành nhiều lầu, có màu sơn đỏ và nét trang trí tạo vẻ cổ kính. Thành phố Châu Đốc có Núi Sam (Vĩnh Tế Sơn), từ đỉnh núi có thể nhìn toàn cảnh Châu Đốc và Kênh Vĩnh Tế. Trên và quanh núi Sam có rất nhiều chùa và miếu, trong đó nổi tiếng nhất là Miếu Bà chúa Xứ, Chùa Tây An, lăng Thoại Ngọc Hầu, Chùa Phước Điền. . . Chùa Tây An Chùa Tây An nằm ở chân núi Sam (xã Vĩnh Tế, thành phố Châu Đốc) xây dựng vào năm 1847, mang dáng dấp của một công trình kiến trúc Ấn Độ. Ngôi cổ tự đã được Bộ Văn hóa xếp hạng là di tích kiến trúc nghệ thuật cấp quốc gia. Đây cũng là ngôi chùa mang kiến trúc Việt kết hợp với Ấn Độ đầu tiên ở Việt Nam. Chợ Châu Đốc được xem như "vương quốc mắm". Ảnh: Quỳnh Trần Chợ Châu Đốc Chợ nằm ở trung tâm thành phố Châu Đốc, bán các đặc sản địa phương chế biến ngay tại chỗ và mua về, với rất nhiều sạp bán mắm và khô đủ loại. Nếu là lần đầu tiên về miền Tây, đừng bỏ qua chợ Châu Đốc với những trải nghiệm th ...

# %%
if result['success']:
    # In tóm tắt
    print(f"\n[FILE ID: {result['file_id']}] | Title: {result['title']}")
    print(f"Clean Length: {result['clean_length']}")
    
    # In nội dung (giới hạn 500 ký tự để xem trước)
    preview = result['clean_text'][:] + "..." if result['clean_length'] > 500 else result['clean_text']
    print(f"\nNội dung trích xuất:\n{'-'*50}\n{preview}\n{'-'*50}")
# Out:
# [FILE ID: 0] | Title: Cẩm nang du lịch An Giang 2024: 12 địa điểm vui chơi phải trải nghiệm
# Clean Length: 9753
#
# Nội dung trích xuất:
# --------------------------------------------------
# Thông báo Ý kiến Tin đã xem Bật nhận thông báo Đang tải dữ liệu. . . Trở lại Du lịch Điều hướng nhanh An Giang mùa nào đẹp? Khách sạn, homestay Đặc sản An Giang Mua gì làm quà An Giang là tỉnh ở miền Tây Nam Bộ, một phần trong vùng tứ giác Long Xuyên. Tỉnh thuộc vùng đồng bằng sông Cửu Long, có sông Tiền và sông Hậu chảy qua. Đường biên giới dài gần 100 km giáp Campuchia. An Giang mùa nào đẹp? Từ tháng 3 đến tháng 5, An Giang trong mùa nắng khô ráo. Nếu muốn ngắm thảm bèo cũng như thế giới tự nhiên xanh mát ở rừng tràm Trà Sư vào mùa nước nổi, bạn nên đi vào tháng 10 và 11. Cuối tháng 11 đến đầu tháng 12, bạn có thể chiêm ngưỡng những cánh đồng lúa chín vào mùa gặt ở Tà Pạ. Vào tháng 4 hay tháng 8 âm lịch là thời gian diễn ra hai lễ hội lớn gồm hội bà Chúa Xứ núi Sam (23 - 27/4 âm lịch) và lễ hội đua bò cuối tháng 8. Các tháng 7 - 8 có mưa khá nhiều nên bạn cần mang theo ô và trang phục phù hợp.
xứ, Chùa Tây An, lăng Thoại Ngọc Hầu, Chùa Phước Điền. . . Chùa Tây An Chùa Tây An nằm ở chân núi Sam (xã Vĩnh Tế, thành phố Châu Đốc) xây dựng vào năm 1847, mang dáng dấp của một công trình kiến trúc Ấn Độ. Ngôi cổ tự đã được Bộ Văn hóa xếp hạng là di tích kiến trúc nghệ thuật cấp quốc gia. Đây cũng là ngôi chùa mang kiến trúc Việt kết hợp với Ấn Độ đầu tiên ở Việt Nam. Chợ Châu Đốc được xem như "vương quốc mắm". Ảnh: Quỳnh Trần Chợ Châu Đốc Chợ nằm ở trung tâm thành phố Châu Đốc, bán các đặc sản địa phương chế biến ngay tại chỗ và mua về, với rất nhiều sạp bán mắm và khô đủ loại. Nếu là lần đầu tiên về miền Tây, đừng bỏ qua chợ Châu Đốc với những trải nghiệm th ...
# --------------------------------------------------

# %% [markdown]
# ## Xu ly toan bo file html

# %%
# HÀM XỬ LÝ TẤT CẢ FILE VÀ LƯU KẾT QUẢ THEO TÊN
def process_all_html_files():
    """
    Xử lý tất cả file HTML trong thư mục data
    """
    html_files = [f for f in os.listdir(INPUT_FOLDER) if f.endswith(('.html', '.htm'))]
    
    all_results = []
    url_data = []
    
    print(f"Bắt đầu xử lý {len(html_files)} file HTML...")
    print("=" * 60)
    
    for i, html_file in enumerate(html_files, 1):
        input_path = os.path.join(INPUT_FOLDER, html_file)
        output_filename = html_file.rsplit('.', 1)[0] + '.txt'
        output_path = os.path.join(OUTPUT_FOLDER, output_filename)
        
        print(f"[{i}/{len(html_files)}] Đang xử lý: {html_file}")
           
        file_id = int(html_file.rsplit('.', 1)[0])  # giả sử tên file là id.html
        result = process_html_file(input_path, base_url=base_url, valid_urls=valid_urls, file_id=file_id)
        
        # Lưu file TXT
        if result['success'] and result['clean_text']:
            with open(output_path, 'w', encoding='utf-8') as file:
                file.write(result['clean_text'])
        
        for url in result['urls']:
            url_data.append({
                'id': file_id,
                'title': result['title'],
                'url': url,
                'url_id': url_to_id.get(url, None),
                'source_file': html_file
            })

        
        all_results.append(result)
        
        print(f"Nội dung: {result['clean_length']} ký tự")
        print(f"URL: {len(result['urls'])} liên kết")
        if result['clean_length'] < 20:
            print("==============Cảnh báo: Nội dung quá ngắn!============")
    
    # LƯU FILE CSV CHỨA URL LIÊN QUAN
    if url_data:
        df_urls = pd.DataFrame(url_data)
        df_urls.to_csv(URLS_CSV, index=False, encoding='utf-8')
        print(f"\nĐã lưu {len(url_data)} URL vào: {URLS_CSV}")
    
    return all_results

results = process_all_html_files()
# Out:
# Bắt đầu xử lý 494 file HTML...
# ============================================================
# [1/494] Đang xử lý: 0.html
# Base URL: https://vnexpress.net
# Nội dung: 9753 ký tự
# URL: 1 liên kết
# [2/494] Đang xử lý: 1.html
# Base URL: https://vnexpress.net
# Nội dung: 14881 ký tự
# URL: 2 liên kết
# [3/494] Đang xử lý: 10.html
# Base URL: https://vnexpress.net
# Nội dung: 10558 ký tự
# URL: 2 liên kết
# [4/494] Đang xử lý: 100.html
# Base URL: https://vnexpress.net
# Nội dung: 15901 ký tự
# URL: 1 liên kết
# [5/494] Đang xử lý: 101.html
# Base URL: https://vnexpress.net
# Nội dung: 17306 ký tự
# URL: 1 liên kết
# [6/494] Đang xử lý: 102.html
# Base URL: https://vnexpress.net
# Nội dung: 14114 ký tự
# URL: 0 liên kết
# [7/494] Đang xử lý: 103.html
# Base URL: https://vnexpress.net
# Nội dung: 15035 ký tự
# URL: 0 liên kết
# [8/494] Đang xử lý: 104.html
# Base URL: https://vnexpress.net
# Nội dung: 17239 ký tự
# URL: 1 liên kết
# [9/494] Đang xử lý: 105.html
# Base URL: https://vnexpress.net
# Nội dung: 8691 ký tự
# URL: 2 liên kết
# [10/494] Đang xử lý: 106.html
# Base URL: https://vnexpress.net
# Nội dung: 10505 ký tự
# URL: 2 liên kết
# [11/494] Đang xử lý: 107.html
# Base URL: https://vnexpress.net
# Nội dung: 11294 ký tự
# URL: 4 liên kết
# [12/494] Đang xử lý: 108.html
# Base URL: https://vnexpress.net
# Nội dung: 16812 ký tự
# URL: 1 liên kết
# [13/494] Đang xử lý: 109.html
# Base URL: https://vnexpress.net
# Nội dung: 23706 ký tự
# URL: 5 liên kết
# [14/494] Đang xử lý: 11.html
# Base URL: https://vnexpress.net
# Nội dung: 17409 ký tự
# URL: 5 liên kết
# [15/494] Đang xử lý: 110.html
# Base URL: https://vnexpress.net
# Nội dung: 16808 ký tự
# URL: 3 liên kết
# [16/494] Đang xử lý: 111.html
# Base URL: https://vnexpress.net
# Nội dung: 8643 ký tự
# URL: 3 liên kết
# [17/494] Đang xử lý: 112.html
# Base URL: https://vnexpress.net
# Nội dung: 14465 ký tự
# URL: 2 liên kết
# [18/494] Đang xử lý: 113.html
# Base URL: https://vnexpress.net
# Nội dung: 10570 ký tự
# URL: 2 liên kết
# [19/494] Đang xử lý: 114.html
# Base URL: https://vnexpress.net
# Nội dung: 26002 ký tự
# URL: 3 liên kết
# [20/494] Đang xử lý: 115.html
# Base URL: https://vnexpress.net
# Nội dung: 7981 ký tự
# URL: 0 liên kết
# [21/494] Đang xử lý: 116.html
# Base URL: https://vnexpress.net
# Nội dung: 10375 ký tự
# URL: 2 liên kết
# [22/494] Đang xử lý: 117.html
# Base URL: https://vnexpress.net
# Nội dung: 11788 ký tự
# URL: 2 liên kết
# [23/494] Đang xử lý: 118.html
# Base URL: https://vnexpress.net
# Nội dung: 15881 ký tự
# URL: 1 liên kết
# [24/494] Đang xử lý: 119.html
# Base URL: https://vnexpress.net
# Nội dung: 10740 ký tự
# URL: 2 liên kết
# [25/494] Đang xử lý: 12.html
# Base URL: https://vnexpress.net
# Nội dung: 12574 ký tự
# URL: 1 liên kết
# [26/494] Đang xử lý: 120.html
# Base URL: https://vnexpress.net
# Nội dung: 17495 ký tự
# URL: 1 liên kết
# [27/494] Đang xử lý: 121.html
# Base URL: https://vnexpress.net
# Nội dung: 11950 ký tự
# URL: 3 liên kết
html
# Base URL: https://vi.wikipedia.org
# Nội dung: 10539 ký tự
# URL: 8 liên kết
# [121/494] Đang xử lý: 206.html
# Base URL: https://vinpearl.com
# Nội dung: 84 ký tự
# URL: 0 liên kết
# [122/494] Đang xử lý: 207.html
# Base URL: https://vi.wikipedia.org
# Nội dung: 11776 ký tự
# URL: 8 liên kết
# [123/494] Đang xử lý: 208.html
# Base URL: https://vinpearl.com
# Nội dung: 84 ký tự
# URL: 0 liên kết
# [124/494] Đang xử lý: 209.html
# Base URL: https://vi.wikipedia.org
# Nội dung: 9701 ký tự
# URL: 28 liên kết
# [125/494] Đang xử lý: 21.html
# Base URL: https://vnexpress.net
# Nội dung: 11362 ký tự
# URL: 2 liên kết
# [126/494] Đang xử lý: 210.html
# Base URL: https://tapchimoitruong.vn
# Nội dung: 3592 ký tự
# URL: 0 liên kết
# [127/494] Đang xử lý: 211.html
# Base URL: https://www.traveloka.com
# Nội dung: 9793 ký tự
# URL: 0 liên kết
# [128/494] Đang xử lý: 212.html
# Base URL: https://www.traveloka.com
# Nội dung: 12308 ký tự
# URL: 0 liên kết
# [129/494] Đang xử lý: 213.html
# Base URL: https://vietair.com.vn
# Nội dung: 10918 ký tự
# URL: 1 liên kết
# [130/494] Đang xử lý: 214.html
# Base URL: https://vi.wikipedia.org
# Nội dung: 13825 ký tự
# URL: 7 liên kết
# [131/494] Đang xử lý: 215.html
# Base URL: https://vinpearl.com
# Nội dung: 83 ký tự
# URL: 0 liên kết
# [132/494] Đang xử lý: 216.html
# Base URL: https://vi.wikipedia.org
# Nội dung: 13356 ký tự
# URL: 32 liên kết
# [133/494] Đang xử lý: 217.html
# Base URL: https://www.traveloka.com
# Nội dung: 10872 ký tự
# URL: 0 liên kết
# [134/494] Đang xử lý: 218.html
# Base URL: https://vi.wikipedia.org
# Nội dung: 20617 ký tự
# URL: 2 liên kết
# [135/494] Đang xử lý: 219.html
# Base URL: https://vi.wikipedia.org
# Nội dung: 7646 ký tự
# URL: 2 liên kết
# [136/494] Đang xử lý: 22.html
# Base URL: https://vnexpress.net
# Nội dung: 8105 ký tự
# URL: 1 liên kết
# [137/494] Đang xử lý: 220.html
# Base URL: https://mia.vn
# Nội dung: 10407 ký tự
# URL: 1 liên kết
# [138/494] Đang xử lý: 221.html
# Base URL: https://vi.wikipedia.org
# Nội dung: 8173 ký tự
# URL: 2 liên kết
# [139/494] Đang xử lý: 222.html
# Base URL: https://www.traveloka.com
# Nội dung: 11989 ký tự
# URL: 0 liên kết
# [140/494] Đang xử lý: 223.html
# Base URL: https://vinpearl.com
# Nội dung: 83 ký tự
# URL: 0 liên kết
# [141/494] Đang xử lý: 224.html
# Base URL: https://vi.wikipedia.org
# Nội dung: 15112 ký tự
# URL: 2 liên kết
# [142/494] Đang xử lý: 225.html
# Base URL: https://mia.vn
# Nội dung: 8469 ký tự
# URL: 1 liên kết
# [143/494] Đang xử lý: 226.html
# Base URL: https://www.traveloka.com
# Nội dung: 6739 ký tự
# URL: 0 liên kết
# [144/494] Đang xử lý: 227.html
# Base URL: https://vi.wikipedia.org
# Nội dung: 3834 ký tự
# URL: 1 liên kết
# [145/494] Đang xử lý: 228.html
# Base URL: https://vi.wikipedia.org
# Nội dung: 9866 ký tự
# URL: 1 liên kết
# [146/494] Đang xử lý: 229.html
# Base URL: https://vietluxtour.com
# Nội dung: 9473 ký tự
# URL: 0 liên kết
# [147/494] Đang xử lý: 23.html
# Base URL: https://vnexpress.net
# Nội dung: 12976 ký tự
# URL: 2 liên kết
# [148/494] Đang xử lý: 230.html
# Base URL: https://vi.wikipedia.org
# Nội dung: 11001 ký tự
# URL: 28 liên kết
# [149/494] Đang xử lý: 231.html
# Base URL: https://vinpearl.com
# Nội dung: 83 ký tự
# URL: 0 liên kết
#
html
# Base URL: https://thamhiemmekong.com
# Nội dung: 7304 ký tự
# URL: 0 liên kết
# [343/494] Đang xử lý: 407.html
# Base URL: https://www.traveloka.com
# Nội dung: 5941 ký tự
# URL: 0 liên kết
# [344/494] Đang xử lý: 408.html
# Base URL: https://www.ivivu.com
# Nội dung: 8675 ký tự
# URL: 0 liên kết
# [345/494] Đang xử lý: 409.html
# Base URL: https://mia.vn
# Nội dung: 7662 ký tự
# URL: 0 liên kết
# [346/494] Đang xử lý: 41.html
# Base URL: https://vnexpress.net
# Nội dung: 18161 ký tự
# URL: 1 liên kết
# [347/494] Đang xử lý: 410.html
# Base URL: https://dulichthuduc.com.vn
# Nội dung: 9437 ký tự
# URL: 1 liên kết
# [348/494] Đang xử lý: 411.html
# Base URL: https://mia.vn
# Nội dung: 8945 ký tự
# URL: 2 liên kết
# [349/494] Đang xử lý: 412.html
# Base URL: https://vnexpress.net
# Nội dung: 11992 ký tự
# URL: 1 liên kết
# [350/494] Đang xử lý: 413.html
# Base URL: https://vinpearl.com
# Nội dung: 83 ký tự
# URL: 0 liên kết
# [351/494] Đang xử lý: 414.html
# Base URL: https://www.traveloka.com
# Nội dung: 18632 ký tự
# URL: 0 liên kết
# [352/494] Đang xử lý: 415.html
# Base URL: https://mia.vn
# Nội dung: 12003 ký tự
# URL: 1 liên kết
# [353/494] Đang xử lý: 416.html
# Base URL: https://vinpearl.com
# Nội dung: 83 ký tự
# URL: 0 liên kết
# [354/494] Đang xử lý: 417.html
# Base URL: https://luhanhvietnam.com.vn
# Nội dung: 8033 ký tự
# URL: 0 liên kết
# [355/494] Đang xử lý: 418.html
# Base URL: https://vinwonders.com
# Nội dung: 30919 ký tự
# URL: 1 liên kết
# [356/494] Đang xử lý: 419.html
# Base URL: https://vinpearl.com
# Nội dung: 83 ký tự
# URL: 0 liên kết
# [357/494] Đang xử lý: 42.html
# Base URL: https://vnexpress.net
# Nội dung: 12493 ký tự
# URL: 1 liên kết
# [358/494] Đang xử lý: 420.html
# Base URL: https://www.ivivu.com
# Nội dung: 7745 ký tự
# URL: 0 liên kết
# [359/494] Đang xử lý: 421.html
# Base URL: https://www.traveloka.com
# Nội dung: 8915 ký tự
# URL: 0 liên kết
# [360/494] Đang xử lý: 422.html
# Base URL: https://www.traveloka.com
# Nội dung: 10777 ký tự
# URL: 0 liên kết
# [361/494] Đang xử lý: 423.html
# Base URL: https://www.ivivu.com
# Nội dung: 8159 ký tự
# URL: 0 liên kết
# [362/494] Đang xử lý: 424.html
# Base URL: https://vinwonders.com
# Nội dung: 32314 ký tự
# URL: 1 liên kết
# [363/494] Đang xử lý: 425.html
# Base URL: https://vietgoing.com
# Nội dung: 12188 ký tự
# URL: 0 liên kết
# [364/494] Đang xử lý: 426.html
# Base URL: https://www.traveloka.com
# Nội dung: 13323 ký tự
# URL: 0 liên kết
# [365/494] Đang xử lý: 427.html
# Base URL: https://bariavungtautourism.com.vn
# Nội dung: 21743 ký tự
# URL: 1 liên kết
# [366/494] Đang xử lý: 428.html
# Base URL: https://thamhiemmekong.com
# Nội dung: 10278 ký tự
# URL: 1 liên kết
# [367/494] Đang xử lý: 429.html
# Base URL: https://luhanhvietnam.com.vn
# Nội dung: 7836 ký tự
# URL: 0 liên kết
# [368/494] Đang xử lý: 43.html
# Base URL: https://vnexpress.net
# Nội dung: 15012 ký tự
# URL: 1 liên kết
# [369/494] Đang xử lý: 430.html
# Base URL: https://www.traveloka.com
# Nội dung: 10192 ký tự
# URL: 0 liên kết
# [370/494] Đang xử lý: 431.html
# Base URL: https://thamhiemmekong.com
# Nội dung: 10170 ký tự
# URL: 1 liên kết
# [371/494] Đang xử lý: 432.html
# Base URL: https://thamhiemmekong.com
# Nội dung:
# URL: 0 liên kết
# [399/494] Đang xử lý: 459.html
# Base URL: https://www.traveloka.com
# Nội dung: 7526 ký tự
# URL: 0 liên kết
# [400/494] Đang xử lý: 46.html
# Base URL: https://vnexpress.net
# Nội dung: 13242 ký tự
# URL: 2 liên kết
# [401/494] Đang xử lý: 460.html
# Base URL: https://www.ivivu.com
# Nội dung: 11325 ký tự
# URL: 0 liên kết
# [402/494] Đang xử lý: 461.html
# Base URL: https://www.traveloka.com
# Nội dung: 9636 ký tự
# URL: 0 liên kết
# [403/494] Đang xử lý: 462.html
# Base URL: https://vinwonders.com
# Nội dung: 32428 ký tự
# URL: 1 liên kết
# [404/494] Đang xử lý: 463.html
# Base URL: https://www.ivivu.com
# Nội dung: 13361 ký tự
# URL: 0 liên kết
# [405/494] Đang xử lý: 464.html
# Base URL: https://dulichokela.com
# Nội dung: 19563 ký tự
# URL: 1 liên kết
# [406/494] Đang xử lý: 465.html
# Base URL: https://motogo.vn
# Nội dung: 12490 ký tự
# URL: 0 liên kết
# [407/494] Đang xử lý: 466.html
# Base URL: https://mia.vn
# Nội dung: 8493 ký tự
# URL: 0 liên kết
# [408/494] Đang xử lý: 467.html
# Base URL: https://www.traveloka.com
# Nội dung: 11336 ký tự
# URL: 0 liên kết
# [409/494] Đang xử lý: 468.html
# Base URL: https://thamhiemmekong.com
# Nội dung: 15852 ký tự
# URL: 1 liên kết
# [410/494] Đang xử lý: 469.html
# Base URL: https://www.traveloka.com
# Nội dung: 8667 ký tự
# URL: 0 liên kết
# [411/494] Đang xử lý: 47.html
# Base URL: https://vnexpress.net
# Nội dung: 13206 ký tự
# URL: 2 liên kết
# [412/494] Đang xử lý: 470.html
# Base URL: https://www.vntrip.vn
# Nội dung: 8642 ký tự
# URL: 0 liên kết
# [413/494] Đang xử lý: 471.html
# Base URL: https://www.xanhsm.com
# Nội dung: 12553 ký tự
# URL: 1 liên kết
# [414/494] Đang xử lý: 472.html
# Base URL: https://www.ivivu.com
# Nội dung: 13557 ký tự
# URL: 0 liên kết
# [415/494] Đang xử lý: 473.html
# Base URL: https://vinwonders.com
# Nội dung: 18381 ký tự
# URL: 1 liên kết
# [416/494] Đang xử lý: 474.html
# Base URL: https://www.traveloka.com
# Nội dung: 14176 ký tự
# URL: 0 liên kết
# [417/494] Đang xử lý: 475.html
# Base URL: https://vinpearl.com
# Nội dung: 83 ký tự
# URL: 0 liên kết
# [418/494] Đang xử lý: 476.html
# Base URL: https://vinwonders.com
# Nội dung: 22184 ký tự
# URL: 1 liên kết
# [419/494] Đang xử lý: 477.html
# Base URL: https://vinpearl.com
# Nội dung: 83 ký tự
# URL: 0 liên kết
# [420/494] Đang xử lý: 478.html
# Base URL: https://www.vntrip.vn
# Nội dung: 9845 ký tự
# URL: 0 liên kết
# [421/494] Đang xử lý: 479.html
# Base URL: https://www.ivivu.com
# Nội dung: 15814 ký tự
# URL: 0 liên kết
# [422/494] Đang xử lý: 48.html
# Base URL: https://vnexpress.net
# Nội dung: 16458 ký tự
# URL: 2 liên kết
# [423/494] Đang xử lý: 480.html
# Base URL: https://mia.vn
# Nội dung: 15821 ký tự
# URL: 2 liên kết
# [424/494] Đang xử lý: 481.html
# Base URL: https://www.ivivu.com
# Nội dung: 10451 ký tự
# URL: 0 liên kết
# [425/494] Đang xử lý: 482.html
# Base URL: https://www.xanhsm.com
# Nội dung: 12911 ký tự
# URL: 0 liên kết
# [426/494] Đang xử lý: 483.html
# Base URL: https://vinwonders.com
# Nội dung: 24823 ký tự
# URL: 2 liên kết
# [427/494] Đang xử lý: 484.html
# Base URL: https://vinwonders.com
# Nội dung: 17980 ký tự
# URL: 1 liên kết
# [428/494] Đang xử lý: 485.html
# Base URL: https://www.klook.com
# Nội dung: 12975 ký tự
# URL: 0 liên kết
# [429/494] Đang xử lý: 486.html
# Base URL: https://motogo.vn
# Nội dung: 11081 ký tự
# URL: 0 liên kết
# [430/494] Đang xử lý: 487.html
# Base URL: https://mia.vn
# Nội dung: 8731 ký tự
# URL: 1 liên kết
# [431/494] Đang xử lý: 488.html
# Base URL: https://www.traveloka.com
# Nội dung: 14657 ký tự
# URL: 0 liên kết
# [432/494] Đang xử lý: 489.html
# Base URL: https://motogo.vn
# Nội dung: 13721 ký tự
# URL: 0 liên kết
# [433/494] Đang xử lý: 49.html
# Base URL: https://vnexpress.net
# Nội dung: 23368 ký tự
# URL: 2 liên kết
# [434/494] Đang xử lý: 490.html
# Base URL: https://antamtour.vn
# Nội dung: 13037 ký tự
# URL: 0 liên kết
# [435/494] Đang xử lý: 491.html
# Base URL: https://vinwonders.com
# Nội dung: 31747 ký tự
# URL: 1 liên kết
# [436/494] Đang xử lý: 492.html
# Base URL: https://www.ivivu.com
# Nội dung: 9008 ký tự
# URL: 0 liên kết
# [437/494] Đang xử lý: 493.html
# Base URL: https://mia.vn
# Nội dung: 8625 ký tự
# URL: 0 liên kết
# [438/494] Đang xử lý: 494.html
# Base URL: https://mia.vn
# Nội dung: 8405 ký tự
# URL: 0 liên kết
# [439/494] Đang xử lý: 495.html
# Base URL: https://www.ivivu.com
# Nội dung: 9089 ký tự
# URL: 0 liên kết
# [440/494] Đang xử lý: 5.html
# Base URL: https://vnexpress.net
# Nội dung: 18812 ký tự
# URL: 1 liên kết
# [441/494] Đang xử lý: 50.html
# Base URL: https://vnexpress.net
# Nội dung: 17536 ký tự
# URL: 2 liên kết
# [442/494] Đang xử lý: 51.html
# Base URL: https://vnexpress.net
# Nội dung: 15744 ký tự
# URL: 2 liên kết
# [443/494] Đang xử lý: 52.html
# Base URL: https://vnexpress.net
# Nội dung: 18516 ký tự
# URL: 3 liên kết
# [444/494] Đang xử lý: 53.html
# Base URL: https://vnexpress.net
# Nội dung: 7174 ký tự
# URL: 0 liên kết
# [445/494] Đang xử lý: 54.html
# Base URL: https://vnexpress.net
# Nội dung: 8498 ký tự
# URL: 0 liên kết
# [446/494] Đang xử lý: 55.html
# Base URL: https://vnexpress.net
# Nội dung: 16484 ký tự
# URL: 4 liên kết
# [447/494] Đang xử lý: 56.html
# Base URL: https://vnexpress.net
# Nội dung: 14940 ký tự
# URL: 2 liên kết
# [448/494] Đang xử lý: 57.html
# Base URL: https://vnexpress.net
# Nội dung: 12164 ký tự
# URL: 2 liên kết
# [449/494] Đang xử lý: 58.html
# Base URL: https://vnexpress.net
# Nội dung: 7436 ký tự
# URL: 3 liên kết
# [450/494] Đang xử lý: 59.html
# Base URL: https://vnexpress.net
# Nội dung: 7436 ký tự
# URL: 3 liên kết
# [451/494] Đang xử lý: 6.html
# Base URL: https://vnexpress.net
# Nội dung: 16073 ký tự
# URL: 1 liên kết
# [452/494] Đang xử lý: 60.html
# Base URL: https://vnexpress.net
# Nội dung: 13529 ký tự
# URL: 1 liên kết
# [453/494] Đang xử lý: 61.html
# Base URL: https://vnexpress.net
# Nội dung: 11947 ký tự
# URL: 1 liên kết
# [454/494] Đang xử lý: 62.html
# Base URL: https://vnexpress.net
# Nội dung: 15831 ký tự
# URL: 2 liên kết
# [455/494] Đang xử lý: 63.html
# Base URL: https://vnexpress.net
# Nội dung: 17242 ký tự
# URL: 1 liên kết
# [456/494] Đang xử lý: 64.html
# Base URL: https://vnexpress.net
# Nội dung: 10001 ký tự
# URL: 2 liên kết
# [457/494] Đang xử lý: 65.html
# Base URL: https://vnexpress.net
# Nội dung: 12176 ký tự
# URL: 1 liên kết
# [458/494] Đang xử lý: 66.html
# Base URL: https://vnexpress.net
# Nội dung: 8577 ký tự
# URL: 3 liên kết
# [459/494] Đang xử lý: 67.html
# Base URL: https://vnexpress.net
# Nội dung: 10720 ký tự
# URL: 2 liên kết
# [460/494] Đang xử lý: 68.html
# Base URL: https://vnexpress.net
# Nội dung: 10004 ký tự
# URL: 2 liên kết
# [461/494] Đang xử lý: 69.html
# Base URL: https://vnexpress.net
# Nội dung: 11751 ký tự
# URL: 2 liên kết
# [462/494] Đang xử lý: 7.html
# Base URL: https://vnexpress.net
# Nội dung: 11607 ký tự
# URL: 2 liên kết
# [463/494] Đang xử lý: 70.html
# Base URL: https://vnexpress.net
# Nội dung: 12799 ký tự
# URL: 3 liên kết
# [464/494] Đang xử lý: 71.html
# Base URL: https://vnexpress.net
# Nội dung: 14155 ký tự
# URL: 2 liên kết
# [465/494] Đang xử lý: 72.html
# Base URL: https://vnexpress.net
# Nội dung: 12525 ký tự
# URL: 2 liên kết
# [466/494] Đang xử lý: 73.html
# Base URL: https://vnexpress.net
# Nội dung: 10395 ký tự
# URL: 2 liên kết
# [467/494] Đang xử lý: 74.html
# Base URL: https://vnexpress.net
# Nội dung: 11533 ký tự
# URL: 3 liên kết
# [468/494] Đang xử lý: 75.html
# Base URL: https://vnexpress.net
# Nội dung: 14549 ký tự
# URL: 1 liên kết
# [469/494] Đang xử lý: 76.html
# Base URL: https://vnexpress.net
# Nội dung: 16876 ký tự
# URL: 2 liên kết
# [470/494] Đang xử lý: 77.html
# Base URL: https://vnexpress.net
# Nội dung: 11917 ký tự
# URL: 1 liên kết
# [471/494] Đang xử lý: 78.html
# Base URL: https://vnexpress.net
# Nội dung: 12887 ký tự
# URL: 3 liên kết
# [472/494] Đang xử lý: 79.html
# Base URL: https://vnexpress.net
# Nội dung: 15104 ký tự
# URL: 2 liên kết
# [473/494] Đang xử lý: 8.html
# Base URL: https://vnexpress.net
# Nội dung: 11432 ký tự
# URL: 1 liên kết
# [474/494] Đang xử lý: 80.html
# Base URL: https://vnexpress.net
# Nội dung: 6693 ký tự
# URL: 0 liên kết
# [475/494] Đang xử lý: 81.html
# Base URL: https://vnexpress.net
# Nội dung: 17164 ký tự
# URL: 2 liên kết
# [476/494] Đang xử lý: 82.html
# Base URL: https://vnexpress.net
# Nội dung: 15970 ký tự
# URL: 2 liên kết
# [477/494] Đang xử lý: 83.html
# Base URL: https://vnexpress.net
# Nội dung: 10095 ký tự
# URL: 3 liên kết
# [478/494] Đang xử lý: 84.html
# Base URL: https://vnexpress.net
# Nội dung: 20772 ký tự
# URL: 1 liên kết
# [479/494] Đang xử lý: 85.html
# Base URL: https://vnexpress.net
# Nội dung: 10403 ký tự
# URL: 2 liên kết
# [480/494] Đang xử lý: 86.html
# Base URL: https://vnexpress.net
# Nội dung: 10222 ký tự
# URL: 2 liên kết
# [481/494] Đang xử lý: 87.html
# Base URL: https://vnexpress.net
# Nội dung: 23667 ký tự
# URL: 1 liên kết
# [482/494] Đang xử lý: 88.html
# Base URL: https://vnexpress.net
# Nội dung: 13205 ký tự
# URL: 1 liên kết
# [483/494] Đang xử lý: 89.html
# Base URL: https://vnexpress.net
# Nội dung: 32179 ký tự
# URL: 1 liên kết
# [484/494] Đang xử lý: 9.html
# Base URL: https://vnexpress.net
# Nội dung: 22238 ký tự
# URL: 4 liên kết
# [485/494] Đang xử lý: 90.html
# Base URL: https://vnexpress.net
# Nội dung: 16353 ký tự
# URL: 2 liên kết
# [486/494] Đang xử lý: 91.html
# Base URL: https://vnexpress.net
# Nội dung: 18843 ký tự
# URL: 2 liên kết
# [487/494] Đang xử lý: 92.html
# Base URL: https://vnexpress.net
# Nội dung: 23800 ký tự
# URL: 1 liên kết
# [488/494] Đang xử lý: 93.html
# Base URL: https://vnexpress.net
# Nội dung: 27248 ký tự
# URL: 5 liên kết
# [489/494] Đang xử lý: 94.html
# Base URL: https://vnexpress.net
# Nội dung: 9391 ký tự
# URL: 3 liên kết
# [490/494] Đang xử lý: 95.html
# Base URL: https://vnexpress.net
# Nội dung: 16139 ký tự
# URL: 3 liên kết
# [491/494] Đang xử lý: 96.html
# Base URL: https://vnexpress.net
# Nội dung: 19341 ký tự
# URL: 1 liên kết
# [492/494] Đang xử lý: 97.html
# Base URL: https://vnexpress.net
# Nội dung: 13284 ký tự
# URL: 6 liên kết
# [493/494] Đang xử lý: 98.html
# Base URL: https://vnexpress.net
# Nội dung: 11870 ký tự
# URL: 2 liên kết
# [494/494] Đang xử lý: 99.html
# Base URL: https://vnexpress.net
# Nội dung: 9214 ký tự
# URL: 2 liên kết
#
# Đã lưu 1824 URL vào: extracted_urls.csv

# %%
# BÁO CÁO KẾT QUẢ
def generate_report(results):
    success_count = sum(1 for r in results if r['success'])
    total_urls = sum(len(r['urls']) for r in results)
    total_clean_chars = sum(r['clean_length'] for r in results)
    
    print("\n" + "=" * 60)
    print("BÁO CÁO KẾT QUẢ XỬ LÝ")
    print("=" * 60)
    print(f"Tổng số file HTML: {len(results)}")
    print(f"File xử lý thành công: {success_count}")
    print(f"File thất bại: {len(results) - success_count}")
    print(f"Tổng số URL trích xuất: {total_urls}")
    print(f"Tổng ký tự văn bản sạch: {total_clean_chars:,}")
    
    # Hiển thị chi tiết 5 file đầu
    print(f"\nCHI TIẾT 5 FILE ĐẦU:")
    print("-" * 50)
    for i, result in enumerate(results[:5]):
        status = "success" if result['success'] else "fail"
        print(f"{status} {result['title'][:50]}...")
        print(f"Ký tự: {result['clean_length']} | URL: {len(result['urls'])}")

generate_report(results)
# Out:
# ============================================================
# BÁO CÁO KẾT QUẢ XỬ LÝ
# ============================================================
# Tổng số file HTML: 494
# File xử lý thành công: 494
# File thất bại: 0
# Tổng số URL trích xuất: 1824
# Tổng ký tự văn bản sạch: 6,982,009
#
# CHI TIẾT 5 FILE ĐẦU:
# --------------------------------------------------
# success Cẩm nang du lịch An Giang 2024: 12 địa điểm vui ch...
# Ký tự: 9753 | URL: 1
# success Cẩm nang Du lịch Bà Nà Hills 2025 từ A-Z: Di chuyể...
# Ký tự: 14881 | URL: 2
# success Cẩm nang Du lịch BÌNH LIÊU 2025 từ A-Z: lưu trú, ă...
# Ký tự: 10558 | URL: 2
# success Kinh nghiệm du lịch Sa Pa 2025 từ A-Z: di chuyển, ...
# Ký tự: 15901 | URL: 1
# success Cẩm nang Du lịch Trà Vinh 2025 từ A-Z: Di chuyển, ...
# Ký tự: 17306 | URL: 1

# %%
# KIỂM TRA KẾT QUẢ
def verify_results():
    
    txt_files = [f for f in os.listdir(OUTPUT_FOLDER) if f.endswith('.txt')]
    
    print(f"\nKIỂM TRA KẾT QUẢ:")
    print(f"Số file TXT đã tạo: {len(txt_files)}")
    
    # Kiểm tra 3 file đầu
    for txt_file in txt_files[:3]:
        file_path = os.path.join(OUTPUT_FOLDER, txt_file)
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
        
        print(f"\n{txt_file}:")
        print(f"Độ dài: {len(content)} ký tự")
        print(f"Nội dung: {content[:100]}...")

verify_results()
# Out:
# KIỂM TRA KẾT QUẢ:
# Số file TXT đã tạo: 494
#
# 0.txt:
# Độ dài: 9753 ký tự
# Nội dung: Thông báo Ý kiến Tin đã xem Bật nhận thông báo Đang tải dữ liệu. . . Trở lại Du lịch Điều hướng nhan...
#
# 1.txt:
# Độ dài: 14881 ký tự
# Nội dung: Thông báo Ý kiến Tin đã xem Bật nhận thông báo Đang tải dữ liệu. . . Khu du lịch Bà Nà Hills Trở lại...
#
# 10.txt:
# Độ dài: 10558 ký tự
# Nội dung: Thông báo Ý kiến Tin đã xem Bật nhận thông báo Đang tải dữ liệu. . . Trở lại Du lịch Điều hướng nhan...
