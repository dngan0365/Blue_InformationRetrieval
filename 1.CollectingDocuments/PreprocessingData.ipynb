# %%
import os
import re
import csv
from bs4 import BeautifulSoup
import pandas as pd
from urllib.parse import urljoin, urlparse
import requests

# %%
# Cấu hình đường dẫn
INPUT_FOLDER = "data"  
OUTPUT_FOLDER = "data_clean"  
URLS_CSV = "extracted_urls.csv"  

# Tạo thư mục output nếu chưa tồn tại
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# %%
# HÀM LOẠI BỎ CÁC THÀNH PHẦN KHÔNG CẦN THIẾT
def remove_unwanted_elements(soup):

    # Tạo bản sao để không làm hỏng soup gốc
    clean_soup = BeautifulSoup(str(soup), 'html.parser')
    
    elements_to_remove = [
        'script', 'style', 'link', 'meta', 'noscript', 'video', 'audio'
        'footer', 'header', 'nav', 'aside', 'menu', 'img', 'button'
        'iframe', 'embed', 'object', 'ins', 'path', 'svg', 'symbol'
    ]
    
    for tag in elements_to_remove:
        for element in clean_soup.find_all(tag):
            element.decompose()

    return clean_soup

# %%
# HÀM TRÍCH XUẤT NỘI DUNG CHÍNH
def extract_main_content(soup):
    all_content = []

    text_elements = soup.find_all(['p', 'h1', 'h2', 'h3', 'h4', 'h5', 'h6', 'li'])
    for elem in text_elements:
        text = elem.get_text(separator=' ', strip=True)
        all_content.append(text)
    
    return '\n'.join(all_content)

# %%
# HÀM CHỈNH SỬA TEXT
def normalize_text(text):
    if not text:
        return ""
    
    # Chuẩn hóa khoảng trắng
    text = re.sub(r'\s+', ' ', text)
    
    # Sửa lỗi dấu câu cơ bản
    text = re.sub(r'\s+([.,!?;:])', r'\1', text)  
    text = re.sub(r'([.,!?;:])(\w)', r'\1 \2', text)  
    
    # Loại bỏ ký tự đặc biệt, giữ lại dấu câu tiếng Việt
    text = re.sub(r'[^\w\s.,!?;:()\-ÀÁÂÃÈÉÊÌÍÒÓÔÕÙÚÝàáâãèéêìíòóôõùúýĂăĐđĨĩŨũƠơƯưẠ-ỹ]', ' ', text)
    
    # chuyển về chữ thường
    text = text.lower()

    # Chuẩn hóa khoảng trắng lần cuối
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# %%
# HÀM TRÍCH XUẤT URL LIÊN QUAN
def extract_related_urls(soup, base_domain="https://vnexpress.net"):
    urls = []
    
    for link in soup.find_all('a', href=True):
        url = link['href'].strip()
        
        # Lọc URL không mong muốn
        if (url and 
            not url.startswith(('javascript:', 'mailto:', 'tel:', '#', 'void(0)')) and
            len(url) > 5):
            
            # Chuẩn hóa URL
            if url.startswith('/'):
                url = urljoin(base_domain, url)
            elif not url.startswith(('http://', 'https://')):
                url = urljoin(base_domain + '/', url)
            
            # Kiểm tra URL hợp lệ
            if is_valid_url(url):
                urls.append(url)
    
    return list(set(urls))  # Loại bỏ trùng lặp

def is_valid_url(url):
    try:
        parsed = urlparse(url)
        return bool(parsed.netloc) and bool(parsed.scheme)
    except:
        return False

# %%
# HÀM XỬ LÝ FILE HTML CHÍNH
def process_html_file(html_file_path):

    try:
        # Đọc file HTML
        with open(html_file_path, 'r', encoding='utf-8', errors='ignore') as file:
            html_content = file.read()
        
        soup = BeautifulSoup(html_content, 'html.parser')
        
        # Lấy tiêu đề trang
        title = soup.title.string if soup.title else os.path.basename(html_file_path)
        
        clean_soup = remove_unwanted_elements(soup)
        
        # LƯU HTML ĐÃ LỌC VÀO THƯ MỤC html_clean
        html_clean_folder = "html_clean"
        os.makedirs(html_clean_folder, exist_ok=True)
        clean_html_filename = os.path.basename(html_file_path)
        clean_html_path = os.path.join(html_clean_folder, clean_html_filename)
        
        with open(clean_html_path, 'w', encoding='utf-8') as file:
            file.write(str(clean_soup))
        
        clean_text = extract_main_content(clean_soup)
        
        if clean_text and len(clean_text) > 0:
            
            clean_text = normalize_text(clean_text)
            
            urls = extract_related_urls(soup)
            
            return {
                'title': title,
                'clean_text': clean_text,
                'urls': urls,
                'clean_length': len(clean_text),
                'success': True,
            }
        else:
            return {
                'title': title,
                'clean_text': "",
                'urls': [],
                'clean_length': 0,
                'success': False,
            }
            
    except Exception as e:
        print(f"Lỗi xử lý {html_file_path}: {str(e)}")
        return {
            'title': os.path.basename(html_file_path),
            'clean_text': "",
            'urls': [],
            'clean_length': 0,
            'success': False,
        }

# %%
# HÀM XỬ LÝ TẤT CẢ FILE VÀ LƯU KẾT QUẢ
def process_all_html_files():
    """
    Xử lý tất cả file HTML trong thư mục data
    """
    html_files = [f for f in os.listdir(INPUT_FOLDER) if f.endswith(('.html', '.htm'))]
    
    all_results = []
    url_data = []
    
    print(f"Bắt đầu xử lý {len(html_files)} file HTML...")
    print("=" * 60)
    
    for i, html_file in enumerate(html_files, 1):
        input_path = os.path.join(INPUT_FOLDER, html_file)
        output_filename = html_file.rsplit('.', 1)[0] + '.txt'
        output_path = os.path.join(OUTPUT_FOLDER, output_filename)
        
        print(f"[{i}/{len(html_files)}] Đang xử lý: {html_file}")
        
        result = process_html_file(input_path)
        
        # Lưu file TXT
        if result['success'] and result['clean_text']:
            with open(output_path, 'w', encoding='utf-8') as file:
                file.write(result['clean_text'])
        
        for url in result['urls']:
            url_data.append({
                'title': result['title'],
                'url': url,
                'source_file': html_file
            })

        
        all_results.append(result)
        
        print(f"Nội dung: {result['clean_length']} ký tự")
        print(f"URL: {len(result['urls'])} liên kết")
    
    # LƯU FILE CSV CHỨA URL LIÊN QUAN
    if url_data:
        df_urls = pd.DataFrame(url_data)
        df_urls.to_csv(URLS_CSV, index=False, encoding='utf-8')
        print(f"\nĐã lưu {len(url_data)} URL vào: {URLS_CSV}")
    
    return all_results

results = process_all_html_files()
# Out:
# Bắt đầu xử lý 407 file HTML...
# ============================================================
# [1/407] Đang xử lý: ao_Hon_Khoai_o_Ca_Mau_-_vung_bien_va_dai_at_phia_Tay_Nam_cua_To_quoc.html
# Nội dung: 14457 ký tự
# URL: 140 liên kết
# [2/407] Đang xử lý: Kinh_nghiem_kham_pha_ho_a_Xanh_Vung_Tau_chi_tiet_nhat_2025.html
# Nội dung: 8587 ký tự
# URL: 104 liên kết
# [3/407] Đang xử lý: Cam_nang_du_lich_Sam_Son.html
# Nội dung: 11554 ký tự
# URL: 68 liên kết
# [4/407] Đang xử lý: Cam_nang_du_lich_Bao_Loc.html
# Nội dung: 11357 ký tự
# URL: 69 liên kết
# [5/407] Đang xử lý: Bien_Ca_Na_Bai_bien_ep_nen_tho_cua_Phan_Rang.html
# Nội dung: 11115 ký tự
# URL: 60 liên kết
# [6/407] Đang xử lý: Top_6_Bai_Bien_Quy_Nhon_ep_Ngat_Ngay_Khong_The_Bo_Qua.html
# Nội dung: 10721 ký tự
# URL: 68 liên kết
# [7/407] Đang xử lý: Cam_nang_du_lich_Ly_Son.html
# Nội dung: 11539 ký tự
# URL: 75 liên kết
# [8/407] Đang xử lý: Nui_Langbiang__Wikipedia_tieng_Viet.html
# Nội dung: 9052 ký tự
# URL: 278 liên kết
# [9/407] Đang xử lý: Kham_pha_ve_ep_ao_xanh_Cu_Lao_Cham.html
# Nội dung: 3745 ký tự
# URL: 91 liên kết
# [10/407] Đang xử lý: Nui_Cam_-_Khu_du_lich_Lam_Vien_Nui_Cam_An_Giang_-_Gia_ve_Cap_Treo.html
# Nội dung: 13127 ký tự
# URL: 51 liên kết
# [11/407] Đang xử lý: Cho_noi_Cai_Rang__Wikipedia_tieng_Viet.html
# Nội dung: 4650 ký tự
# URL: 137 liên kết
# [12/407] Đang xử lý: Kinh_nghiem_du_lich_ban_ao_son_tra_a_Nang_chi_tiet_A_-_Z.html
# Nội dung: 10688 ký tự
# URL: 50 liên kết
# [13/407] Đang xử lý: Dia_dao_Cu_Chi__Wikipedia_tieng_Viet.html
# Nội dung: 18191 ký tự
# URL: 683 liên kết
# [14/407] Đang xử lý: Con_Phung_-_Khu_du_lich_Con_Phung,_Ben_Tre.html
# Nội dung: 8941 ký tự
# URL: 55 liên kết
# [15/407] Đang xử lý: Ho_Xa_Huong__Wikipedia_tieng_Viet.html
# Nội dung: 1994 ký tự
# URL: 107 liên kết
# [16/407] Đang xử lý: Tham_quan_vuon_thu_Thao_Cam_Vien_Sai_Gon_-_Vntrip.vn.html
# Nội dung: 8376 ký tự
# URL: 83 liên kết
# [17/407] Đang xử lý: Vuon_quoc_gia_Nui_Chua__Wikipedia_tieng_Viet.html
# Nội dung: 13774 ký tự
# URL: 194 liên kết
# [18/407] Đang xử lý: Bien_Ho_Coc_Vung_Tau__iem_du_lich,_nghi_duong_ly_tuong.html
# Nội dung: 16736 ký tự
# URL: 78 liên kết
# [19/407] Đang xử lý: Cau_Truong_Tien_-_Cay_cau_lich_su_-_Bieu_tuong_cua_xu_Hue.html
# Nội dung: 10055 ký tự
# URL: 73 liên kết
# [20/407] Đang xử lý: Bien_Ho_Coc_Kinh_nghiem_du_lich_chi_tiet_nam_2025.html
# Nội dung: 13818 ký tự
# URL: 77 liên kết
# [21/407] Đang xử lý: Check-in_ho_a_Xanh_Vung_Tau_-_Toa_o_song_ao_ep_me_hon.html
# Nội dung: 12568 ký tự
# URL: 77 liên kết
# [22/407] Đang xử lý: Cam_nang_du_lich_Yen_Bai.html
# Nội dung: 16130 ký tự
# URL: 75 liên kết
# [23/407] Đang xử lý: Bai_Bien_Ho_Tram,_Ba_Ria_-_Vung_Tau.html
# Nội dung: 10927 ký tự
# URL: 245 liên kết
# [24/407] Đang xử lý: ong_Phong_Nha__Wikipedia_tieng_Viet.html
# Nội dung: 4538 ký tự
# URL: 280 liên kết
# [25/407] Đang xử lý: Ho_Yen_Thang__Wikipedia_tieng_Viet.html
# Nội dung: 4254 ký tự
# URL: 182 liên kết
# [26/407] Đang xử lý: Cam_nang_du_lich_Vinh_Phuc.html
# Nội dung: 8979 ký tự
# URL: 70 liên kết
# [27/407] Đang xử lý: Cam_nang_du_lich_Son_La.html
# Nội dung: 13237 ký tự
# URL: 84 liên kết
# [28/407] Đang xử lý: Cam_nang_du_lich_Quang_Tri.html
# Nội dung: 30382 ký tự
# URL: 88 liên kết
# [29/407] Đang xử lý: Cau_Vang_Ba_Na_Hill__Bieu_Tuong_Du_Lich_a_Nang.html
# Nội dung: 6219 ký tự
# URL: 73 liên kết
# [30/407] Đang xử lý: en_lang_co_uong_Lam_lac_vao_co_tran_binh_yen_ngay_sat_Ha_Noi.html
# Nội dung: 9438 ký tự
# URL: 155 liên kết
# [31/407] Đang xử lý: Cam_nang_du_lich_Hoi_An.html
# Nội dung: 14916 ký tự
# URL: 64 liên kết
# [32/407] Đang xử lý: Tron_bo_kinh_nghiem_du_lich_vuon_Quoc_gia_Phong_Nha_Ke_Bang.html
# Nội dung: 107571 ký tự
# URL: 914 liên kết
# [33/407] Đang xử lý: Cam_nang_du_lich_Ha_Nam.html
# Nội dung: 12477 ký tự
# URL: 62 liên kết
# [34/407] Đang xử lý: Goi_y_lich_trinh_kham_pha_Hon_Nua__Phu_Yen_tu_tuc_2N1.html
# Nội dung: 8873 ký tự
# URL: 47 liên kết
# [35/407] Đang xử lý: Vuon_quoc_gia_Cat_Tien__Wikipedia_tieng_Viet.html
# Nội dung: 12380 ký tự
# URL: 615 liên kết
# [36/407] Đang xử lý: Cam_nang_du_lich_Pu_Luong.html
# Nội dung: 9828 ký tự
# URL: 69 liên kết
# [37/407] Đang xử lý: en_bien_My_Khe_a_Nang,_lang_nguoi_ngam_nhin_1_trong_6_bai_bien_ep_nhat_hanh_tinh.html
# Nội dung: 8771 ký tự
# URL: 47 liên kết
# [38/407] Đang xử lý: Kham_pha_thung_lung_Mai_Chau_ep_lang_man_tai_Mai_Chau_Lodge_Hoa_Binh_-_iVIVU.com.html
# Nội dung: 4218 ký tự
# URL: 232 liên kết
# [39/407] Đang xử lý: Chua_Huong_Tich_-_Ngoi_co_tu_linh_thieng_o_Ha_Tinh.html
# Nội dung: 5956 ký tự
# URL: 55 liên kết
# [40/407] Đang xử lý: Cam_nang_du_lich_Soc_Son.html
# Nội dung: 9030 ký tự
# URL: 57 liên kết
# [41/407] Đang xử lý: Kham_pha_ve_ep_hoang_so_cua_ao_Hon_Khoai_-_Ca_Mau.html
# Nội dung: 8063 ký tự
# URL: 48 liên kết
# [42/407] Đang xử lý: Mui_Ca_Mau,_cuc_nam_cua_To_quoc_-_Bao_VnExpress_Du_lich.html
# Nội dung: 8285 ký tự
# URL: 172 liên kết
# [43/407] Đang xử lý: Vuon_quoc_gia_Cuc_Phuong__Wikipedia_tieng_Viet.html
# Nội dung: 26913 ký tự
# URL: 679 liên kết
# [44/407] Đang xử lý: Ghe_tham_ban_Ta_Phin__Noi_luu_giua_ve_ep_Sapa_xua_cu_-_MOTOGO.html
# Nội dung: 10752 ký tự
# URL: 54 liên kết
# [45/407] Đang xử lý: Son_Tra__Wikipedia_tieng_Viet.html
# Nội dung: 8568 ký tự
# URL: 173 liên kết
# [46/407] Đang xử lý: Cam_nang_du_lich_Quang_Ngai.html
# Nội dung: 18810 ký tự
# URL: 85 liên kết
# [47/407] Đang xử lý: Lac_giua_goc_pho_i_bo_Bui_Vien_nhon_nhip_xuyen_man_em.html
# Nội dung: 9308 ký tự
# URL: 45 liên kết
# [48/407] Đang xử lý: Kham_pha_Hon_Chong_Nha_Trang_Thang_canh_noi_tieng_ben_vinh.html
# Nội dung: 10498 ký tự
# URL: 46 liên kết
# [49/407] Đang xử lý: Lang_gom_Bat_Trang_ia_iem_du_lich_trong_ngay_gan_Ha_Noi_-_Vntrip.vn.html
# Nội dung: 8626 ký tự
# URL: 77 liên kết
# [50/407] Đang xử lý: Ve_An_Giang_ghe_tham_cho_noi_Long_Xuyen_mien_song_nuoc.html
# Nội dung: 3874 ký tự
# URL: 211 liên kết
# [51/407] Đang xử lý: Thac_ung__iem_en_Hap_Dan_O_Binh_Phuoc_Khong_The_Bo_Qua.html
# Nội dung: 10019 ký tự
# URL: 136 liên kết
# [52/407] Đang xử lý: Cam_nang_du_lich_Pho_i_bo_Nguyen_He.html
# Nội dung: 12084 ký tự
# URL: 187 liên kết
# [53/407] Đang xử lý: Nui_Chua_Chan__Wikipedia_tieng_Viet.html
# Nội dung: 18264 ký tự
# URL: 201 liên kết
# [54/407] Đang xử lý: Nui_Ba_en__Wikipedia_tieng_Viet.html
# Nội dung: 18677 ký tự
# URL: 502 liên kết
# [55/407] Đang xử lý: Ghe_tham_ban_Cat_Cat__ngoi_lang_co_ep_nhat_vung_Tay_Bac.html
# Nội dung: 8431 ký tự
# URL: 215 liên kết
# [56/407] Đang xử lý: Cam_nang_du_lich_Buon_Ma_Thuot.html
# Nội dung: 16260 ký tự
# URL: 85 liên kết
# [57/407] Đang xử lý: Kham_pha_oi_che_trai_tim_Moc_Chau_(Bat_mi_thoi_iem_chup_anh_ep_nhat)).html
# Nội dung: 14017 ký tự
# URL: 29 liên kết
# [58/407] Đang xử lý: Cam_nang_du_lich_Vuon_quoc_gia_Cat_Tien.html
# Nội dung: 10489 ký tự
# URL: 72 liên kết
# [59/407] Đang xử lý: Trai_nghiem_i_Cho_Noi_Nga_Nam_-_iem_en_thu_vi_o_Soc_Trang.html
# Nội dung: 5640 ký tự
# URL: 47 liên kết
# [60/407] Đang xử lý: Ho_Ba_Be__Wikipedia_tieng_Viet.html
# Nội dung: 11570 ký tự
# URL: 493 liên kết
# [61/407] Đang xử lý: Thung_Lung_Muong_Hoa_Tuyet_Tac_Thien_uong_Tai_Sapa.html
# Nội dung: 9216 ký tự
# URL: 63 liên kết
# [62/407] Đang xử lý: Co_To_(inh_huong)__Wikipedia_tieng_Viet.html
# Nội dung: 1152 ký tự
# URL: 98 liên kết
# [63/407] Đang xử lý: Kham_pha_nui_Ba_Ra__Ngon_nui_cao_nhat_Binh_Phuoc.html
# Nội dung: 4055 ký tự
# URL: 144 liên kết
# [64/407] Đang xử lý: Cam_nang_du_lich_Meo_Vac.html
# Nội dung: 8575 ký tự
# URL: 66 liên kết
# [65/407] Đang xử lý: CANGIO_-_Khu_Du_Tru_Sinh_Quyen_Rung_Ngap_Man_Can_Gio.html
# Nội dung: 7323 ký tự
# URL: 19 liên kết
# [66/407] Đang xử lý: Cam_nang_du_lich_Ninh_Thuan.html
# Nội dung: 11872 ký tự
# URL: 72 liên kết
# [67/407] Đang xử lý: Khu_du_lich_ai_Nam_co_gi_choi,_cung_Traveloka_review_nhe..html
# Nội dung: 13047 ký tự
# URL: 65 liên kết
# [68/407] Đang xử lý: Cam_nang_du_lich_Thanh_Hoa.html
# Nội dung: 16534 ký tự
# URL: 59 liên kết
# [69/407] Đang xử lý: Thac_Tac_Tinh_-_Ban_tinh_ca_manh_liet_giua_nui_rung_Tay_Bac.html
# Nội dung: 8837 ký tự
# URL: 301 liên kết
# [70/407] Đang xử lý: Nha_Cong_Tu_Bac_Lieu_-_iem_en_khong_the_bo_qua_khi_ve_Bac_Lieu.html
# Nội dung: 9574 ký tự
# URL: 49 liên kết
# [71/407] Đang xử lý: Cam_nang_du_lich_Ba_Vi.html
# Nội dung: 16974 ký tự
# URL: 86 liên kết
# [72/407] Đang xử lý: Cam_nang_du_lich_Ba_Na_Hills.html
# Nội dung: 14543 ký tự
# URL: 61 liên kết
# [73/407] Đang xử lý: Lang_Noi_Ca_Be_Chau_oc_-_Kinh_nghiem_du_lich_Lang_noi_Chau_oc.html
# Nội dung: 9702 ký tự
# URL: 54 liên kết
# [74/407] Đang xử lý: Thac_Dai_Yem_Moc_Chau__Dai_Lua_Trang_Giua_ai_Ngan_Tay_Bac_-_Ecotour.html
# Nội dung: 10236 ký tự
# URL: 68 liên kết
# [75/407] Đang xử lý: ao_Binh_Ba__Wikipedia_tieng_Viet.html
# Nội dung: 2684 ký tự
# URL: 108 liên kết
# [76/407] Đang xử lý: Cam_nang_du_lich_Lam_ong.html
# Nội dung: 7492 ký tự
# URL: 65 liên kết
# [77/407] Đang xử lý: Kinh_nghiem_du_lich_o_Son_Hai_Phong_chi_tiet_nhat_2025.html
# Nội dung: 10714 ký tự
# URL: 69 liên kết
# [78/407] Đang xử lý: Cam_nang_du_lich_Ta_Xua.html
# Nội dung: 10298 ký tự
# URL: 77 liên kết
# [79/407] Đang xử lý: Cam_nang_du_lich_Cu_Lao_Cham.html
# Nội dung: 11832 ký tự
# URL: 65 liên kết
# [80/407] Đang xử lý: Ban_Ta_Phin_-_Vung_at_Van_Hoa_oc_ao_O_Lao_Cai_-_Du_Lich_Okela.html
# Nội dung: 12400 ký tự
# URL: 176 liên kết
# [81/407] Đang xử lý: Rung_tram_Tra_Su_-_he_sinh_thai_ngap_nuoc_vo_cung_phong_phu.html
# Nội dung: 4979 ký tự
# URL: 28 liên kết
# [82/407] Đang xử lý: Ba_Na__Wikipedia_tieng_Viet.html
# Nội dung: 28426 ký tự
# URL: 463 liên kết
# [83/407] Đang xử lý: Cam_nang_du_lich_Hung_Yen.html
# Nội dung: 3431 ký tự
# URL: 171 liên kết
# [84/407] Đang xử lý: Khu_bao_ton_thien_nhien_at_ngap_nuoc_Van_Long__Wikipedia_tieng_Viet.html
# Nội dung: 12216 ký tự
# URL: 251 liên kết
# [85/407] Đang xử lý: Khu_du_lich_Lang_Xanh_Ben_Tre,_toa_o_thu_gian_dip_cuoi_tuan.html
# Nội dung: 8080 ký tự
# URL: 51 liên kết
# [86/407] Đang xử lý: Cua_Lo_(thi_xa)__Wikipedia_tieng_Viet.html
# Nội dung: 18152 ký tự
# URL: 257 liên kết
# [87/407] Đang xử lý: Cam_nang_du_lich_Vinh_Ha_Long.html
# Nội dung: 12596 ký tự
# URL: 74 liên kết
# [88/407] Đang xử lý: Chiem_nguong_Vuon_quoc_gia_U_Minh_Ha,_ve_ep_thien_nhien_tru_phu.html
# Nội dung: 9031 ký tự
# URL: 49 liên kết
# [89/407] Đang xử lý: Khu_du_lich_Con_Phung_Bat_mi_kinh_nghiem_du_ngoan_tu_A-Z.html
# Nội dung: 8787 ký tự
# URL: 55 liên kết
# [90/407] Đang xử lý: Cam_nang_du_lich_Thai_Binh.html
# Nội dung: 4611 ký tự
# URL: 211 liên kết
# [91/407] Đang xử lý: Cua_ai_(phuong)__Wikipedia_tieng_Viet.html
# Nội dung: 2605 ký tự
# URL: 124 liên kết
# [92/407] Đang xử lý: Ru_Nhau_Ve_ak_Nong_Tham_Quan_Thac_Dray_Sap.html
# Nội dung: 9200 ký tự
# URL: 156 liên kết
# [93/407] Đang xử lý: Ruong_bac_thang_Mu_Cang_Chai__Wikipedia_tieng_Viet.html
# Nội dung: 10484 ký tự
# URL: 315 liên kết
# [94/407] Đang xử lý: Bai_Dai_Phu_Quoc_voi_ve_ep_hoang_so,_lan_nuoc_trong_xanh_nhu_ngoc.html
# Nội dung: 8856 ký tự
# URL: 47 liên kết
# [95/407] Đang xử lý: Kinh_nghiem_tham_quan_Dinh_oc_Lap,_bieu_tuong_cua_thong_nhat_va_hoa_binh.html
# Nội dung: 11576 ký tự
# URL: 46 liên kết
# [96/407] Đang xử lý: Cam_nang_du_lich_Bac_Giang.html
# Nội dung: 13083 ký tự
# URL: 67 liên kết
# [97/407] Đang xử lý: Ho_Tuyen_Lam_kham_pha_la_phoi_xanh_cua_a_Lat.html
# Nội dung: 11045 ký tự
# URL: 73 liên kết
# [98/407] Đang xử lý: Khu_du_lich_thac_amb'ri.html
# Nội dung: 1774 ký tự
# URL: 40 liên kết
# [99/407] Đang xử lý: Ho_Lak_vao_top_iem_cam_trai_sang_chanh_o_ong_Nam_A.html
# Nội dung: 1020 ký tự
# URL: 813 liên kết
# [100/407] Đang xử lý: Nha_tho_Con_Ga_a_Lat__Kham_pha_cong_trinh_kien_truc_ton_giao_oc_ao_-_MOTOGO.html
# Nội dung: 12952 ký tự
# URL: 63 liên kết
# [101/407] Đang xử lý: Tan_huong_nhung_trai_nghiem_oc_ao_o_cho_noi_Nga_Bay_Hau_Giang.html
# Nội dung: 11589 ký tự
# URL: 162 liên kết
# [102/407] Đang xử lý: Cu_lao_Cham__Wikipedia_tieng_Viet.html
# Nội dung: 7758 ký tự
# URL: 314 liên kết
# [103/407] Đang xử lý: Cam_nang_du_lich_Khanh_Hoa.html
# Nội dung: 14627 ký tự
# URL: 80 liên kết
# [104/407] Đang xử lý: Lang_gom_Bau_Truc_Ninh_Thuan_-_at_no_hoa_tu_ban_tay_nghe_nhan.html
# Nội dung: 8547 ký tự
# URL: 61 liên kết
# [105/407] Đang xử lý: Cam_nang_du_lich_Cao_Bang.html
# Nội dung: 15889 ký tự
# URL: 88 liên kết
# [106/407] Đang xử lý: Cam_nang_du_lich_Mang_en.html
# Nội dung: 10529 ký tự
# URL: 71 liên kết
# [107/407] Đang xử lý: Cam_nang_du_lich_Tay_Ninh.html
# Nội dung: 14700 ký tự
# URL: 63 liên kết
# [108/407] Đang xử lý: Vuon_Quoc_Gia_Nui_Chua_Khu_du_tru_sinh_quyen_moi_cua_the_gioi.html
# Nội dung: 8961 ký tự
# URL: 49 liên kết
# [109/407] Đang xử lý: Kinh_Nghiem_i_ia_ao_Cu_Chi,_Di_Tich_Noi_Tieng_O_Sai_Gon_-_Klook_Blog.html
# Nội dung: 6727 ký tự
# URL: 414 liên kết
# [110/407] Đang xử lý: Thac_Ban_Gioc_-_ve_ep_ky_vi_giua_non_nuoc_Cao_Bang.html
# Nội dung: 6278 ký tự
# URL: 90 liên kết
# [111/407] Đang xử lý: Ngam_minh_tai_suoi_nuoc_nong_Tien_Lang_Hai_Phong.html
# Nội dung: 8630 ký tự
# URL: 156 liên kết
# [112/407] Đang xử lý: Cam_nang_du_lich_Vinh_Long.html
# Nội dung: 17186 ký tự
# URL: 69 liên kết
# [113/407] Đang xử lý: Cot_co_Lung_Cu_Ha_Giang_-_Bieu_tuong_thieng_lieng_cua_to_quoc.html
# Nội dung: 11204 ký tự
# URL: 66 liên kết
# [114/407] Đang xử lý: Ngu_Hanh_Son__Wikipedia_tieng_Viet.html
# Nội dung: 18889 ký tự
# URL: 536 liên kết
# [115/407] Đang xử lý: Thap_Po_Klong_Garai,_bieu_tuong_ac_sac_cua_van_hoa_Cham_Pa.html
# Nội dung: 9408 ký tự
# URL: 49 liên kết
# [116/407] Đang xử lý: Ghe_tham_chua_Huong_Tich_Ha_Tinh,_ia_iem_tam_linh_o_Ha_Tinh.html
# Nội dung: 15537 ký tự
# URL: 80 liên kết
# [117/407] Đang xử lý: Kinh_nghiem_tham_quan_chua_Huong_Ha_Noi_chi_tiet_nhat.html
# Nội dung: 14431 ký tự
# URL: 35 liên kết
# [118/407] Đang xử lý: Cam_nang_du_lich_Hoa_Binh.html
# Nội dung: 12770 ký tự
# URL: 74 liên kết
# [119/407] Đang xử lý: Bai_bien_Sam_Son__Wikipedia_tieng_Viet.html
# Nội dung: 3256 ký tự
# URL: 263 liên kết
# [120/407] Đang xử lý: ep_hut_hon_canh_sac_thien_nhien_thac_ung_Binh_Phuoc.html
# Nội dung: 8534 ký tự
# URL: 146 liên kết
# [121/407] Đang xử lý: Cam_nang_du_lich_Quang_Binh.html
# Nội dung: 23391 ký tự
# URL: 83 liên kết
# [122/407] Đang xử lý: Kinh_nghiem_kham_pha_Lang_gom_Phu_Lang_Bac_Ninh.html
# Nội dung: 6489 ký tự
# URL: 60 liên kết
# [123/407] Đang xử lý: Khu_du_lich_sinh_thai_ong_Thien_uong_-_Quang_Binh,_Viet_Nam.html
# Nội dung: 583 ký tự
# URL: 75 liên kết
# [124/407] Đang xử lý: Cam_nang_du_lich_vuon_quoc_gia_Pu_Mat,_Nghe_An.html
# Nội dung: 8796 ký tự
# URL: 212 liên kết
# [125/407] Đang xử lý: Cam_nang_du_lich_Pho_i_bo_ho_Guom.html
# Nội dung: 12786 ký tự
# URL: 185 liên kết
# [126/407] Đang xử lý: Cam_nang_du_lich_Vinh_Lan_Ha.html
# Nội dung: 11598 ký tự
# URL: 67 liên kết
# [127/407] Đang xử lý: Chinh_phuc_thac_Lieng_Nung_-_ve_ep_sieu_thuc_cua_Tay_Nguyen.html
# Nội dung: 10911 ký tự
# URL: 63 liên kết
# [128/407] Đang xử lý: oi_Cat_Mui_Ne_Thien_uong_cat_bay_tuyet_ep.html
# Nội dung: 10058 ký tự
# URL: 85 liên kết
# [129/407] Đang xử lý: Ho_Lak_-_iem_du_lich_sinh_thai_va_van_hoa_noi_tieng_cua_ac_Lac.html
# Nội dung: 2414 ký tự
# URL: 39 liên kết
# [130/407] Đang xử lý: Tham_quan_khu_di_tich_en_Hung-Phu_Tho_-_AllTours.html
# Nội dung: 14334 ký tự
# URL: 103 liên kết
# [131/407] Đang xử lý: Vuon_quoc_gia_Xuan_Thuy__Wikipedia_tieng_Viet.html
# Nội dung: 10220 ký tự
# URL: 305 liên kết
# [132/407] Đang xử lý: Cam_nang_du_lich_Can_Gio.html
# Nội dung: 11095 ký tự
# URL: 70 liên kết
# [133/407] Đang xử lý: Quan_ao_Cat_Ba__Wikipedia_tieng_Viet.html
# Nội dung: 24698 ký tự
# URL: 532 liên kết
# [134/407] Đang xử lý: Cau_Rong_a_Nang_Kinh_nghiem_check-in,_tham_quan_chi_tiet.html
# Nội dung: 9161 ký tự
# URL: 44 liên kết
# [135/407] Đang xử lý: Cam_nang_du_lich_Ha_Tien.html
# Nội dung: 12471 ký tự
# URL: 54 liên kết
# [136/407] Đang xử lý: Vuon_quoc_gia_Yok_on__Chon_bong_lai_giua_nui_rung_Tay_Nguyen__Xanh_SM.html
# Nội dung: 12026 ký tự
# URL: 46 liên kết
# [137/407] Đang xử lý: Cam_nang_du_lich_Tra_Su.html
# Nội dung: 8599 ký tự
# URL: 64 liên kết
# [138/407] Đang xử lý: Thap_oi_Quy_Nhon_-_Quy_Nhon_Trip_-_iem_en_Quy_Nhon.html
# Nội dung: 5498 ký tự
# URL: 22 liên kết
# [139/407] Đang xử lý: Cam_nang_du_lich_Cu_Lao_Xanh.html
# Nội dung: 8076 ký tự
# URL: 43 liên kết
# [140/407] Đang xử lý: Thung_Lung_Tinh_Yeu_iem_en_lang_man_va_ay_trai_nghiem.html
# Nội dung: 10536 ký tự
# URL: 47 liên kết
# [141/407] Đang xử lý: Thac_Lieng_Nung_tuyet_ep_thu_hut_tin_o_du_lich_o_Tay_Nguyen_-_iVIVU.com.html
# Nội dung: 3400 ký tự
# URL: 214 liên kết
# [142/407] Đang xử lý: Vuon_quoc_gia_Ba_Be__Wikipedia_tieng_Viet.html
# Nội dung: 9418 ký tự
# URL: 256 liên kết
# [143/407] Đang xử lý: Cam_nang_du_lich_Lai_Chau.html
# Nội dung: 11888 ký tự
# URL: 69 liên kết
# [144/407] Đang xử lý: Chua_Tam_Chuc_Ha_Nam_-_uoc_menh_danh_la_ngoi_chua_lon_nhat_the_gioi.html
# Nội dung: 16403 ký tự
# URL: 176 liên kết
# [145/407] Đang xử lý: Cam_nang_du_lich_Lang_Son.html
# Nội dung: 16979 ký tự
# URL: 72 liên kết
# [146/407] Đang xử lý: Ho_Tuyen_Lam__Wikipedia_tieng_Viet.html
# Nội dung: 7091 ký tự
# URL: 371 liên kết
# [147/407] Đang xử lý: Hoang_thanh_Thang_Long__Wikipedia_tieng_Viet.html
# Nội dung: 53326 ký tự
# URL: 1162 liên kết
# [148/407] Đang xử lý: Quan_the_danh_thang_Trang_An_voi_ve_ep_hung_vi_an_tuong.html
# Nội dung: 14413 ký tự
# URL: 53 liên kết
# [149/407] Đang xử lý: Cam_nang_du_lich_ong_Thap.html
# Nội dung: 14471 ký tự
# URL: 79 liên kết
# [150/407] Đang xử lý: Kinh_nghiem_du_lich_bien_Cua_ai_Hoi_An_tu_A-Z_cho_chuyen_i_tron_niem_vui.html
# Nội dung: 2332 ký tự
# URL: 107 liên kết
# [151/407] Đang xử lý: Lang_gom_Phu_Lang__Lang_gom_noi_tieng_700_nam_xu_Kinh_Bac_-_iVIVU.com.html
# Nội dung: 4535 ký tự
# URL: 225 liên kết
# [152/407] Đang xử lý: Cam_nang_du_lich_Moc_Chau.html
# Nội dung: 13908 ký tự
# URL: 93 liên kết
# [153/407] Đang xử lý: Cam_nang_du_lich_Ninh_Binh.html
# Nội dung: 12961 ký tự
# URL: 87 liên kết
# [154/407] Đang xử lý: Cam_nang_du_lich_Binh_inh.html
# Nội dung: 18111 ký tự
# URL: 75 liên kết
# [155/407] Đang xử lý: Cam_nang_du_lich_Binh_Duong.html
# Nội dung: 18662 ký tự
# URL: 70 liên kết
# [156/407] Đang xử lý: eo_Hai_Van_-_Chinh_phuc_thien_ha_e_nhat_hung_quan.html
# Nội dung: 17730 ký tự
# URL: 76 liên kết
# [157/407] Đang xử lý: Hon_Tam__Wikipedia_tieng_Viet.html
# Nội dung: 11488 ký tự
# URL: 311 liên kết
# [158/407] Đang xử lý: Cam_nang_du_lich_Dinh_oc_lap.html
# Nội dung: 14953 ký tự
# URL: 175 liên kết
# [159/407] Đang xử lý: Chua_Bo_a__Wikipedia_tieng_Viet.html
# Nội dung: 33133 ký tự
# URL: 545 liên kết
# [160/407] Đang xử lý: Nha_cong_tu_Bac_Lieu_-_Kien_truc_be_the_vuot_thoi_gian.html
# Nội dung: 10240 ký tự
# URL: 62 liên kết
# [161/407] Đang xử lý: Thao_Cam_Vien_Sai_Gon__Thien_uong_da_ngoai_giua_o_thi_phon_hoa.html
# Nội dung: 9475 ký tự
# URL: 97 liên kết
# [162/407] Đang xử lý: Pho_i_bo_Bui_Vien__Kham_pha_pho_Tay_soi_ong_cua_em_Sai_thanh.html
# Nội dung: 10310 ký tự
# URL: 95 liên kết
# [163/407] Đang xử lý: Thac_amb'ri__Wikipedia_tieng_Viet.html
# Nội dung: 5538 ký tự
# URL: 411 liên kết
# [164/407] Đang xử lý: Cam_nang_du_lich_Ba_Ria_-_Vung_Tau.html
# Nội dung: 21418 ký tự
# URL: 79 liên kết
# [165/407] Đang xử lý: Quan_the_di_tich_Co_o_Hue__Wikipedia_tieng_Viet.html
# Nội dung: 25530 ký tự
# URL: 585 liên kết
# [166/407] Đang xử lý: Thap_Ba_Ponagar_Nha_Trang_Kinh_nghiem_tham_quan_tu_A-Z.html
# Nội dung: 12609 ký tự
# URL: 83 liên kết
# [167/407] Đang xử lý: Vuon_quoc_gia_Xuan_Thuy,_khu_RAMSAR_oc_nhat_tai_Nam_inh.html
# Nội dung: 11148 ký tự
# URL: 46 liên kết
# [168/407] Đang xử lý: Lang_gom_Phu_Lang_-_Ngoi_lang_co_mang_ve_ep_truyen_thong_tinh_Bac_Ninh.html
# Nội dung: 9302 ký tự
# URL: 305 liên kết
# [169/407] Đang xử lý: Cam_nang_du_lich_Quang_Nam.html
# Nội dung: 16127 ký tự
# URL: 86 liên kết
# [170/407] Đang xử lý: Cam_nang_du_lich_Vuon_quoc_gia_Pu_Mat.html
# Nội dung: 10175 ký tự
# URL: 59 liên kết
# [171/407] Đang xử lý: Cam_nang_du_lich_Hau_Giang.html
# Nội dung: 4749 ký tự
# URL: 187 liên kết
# [172/407] Đang xử lý: Cam_nang_du_lich_Ha_Noi.html
# Nội dung: 21296 ký tự
# URL: 100 liên kết
# [173/407] Đang xử lý: Khu_Du_Lich_Buu_Long,_Toa_o_Vui_Choi_Cuc_Hot_Gan_Sai_Gon_-_Klook_Blog.html
# Nội dung: 6993 ký tự
# URL: 410 liên kết
# [174/407] Đang xử lý: Cam_nang_du_lich_Phu_Quoc.html
# Nội dung: 23407 ký tự
# URL: 83 liên kết
# [175/407] Đang xử lý: Kinh_nghiem_du_lich_Thien_Cam_moi_nhat_-_kham_pha_an_troi.html
# Nội dung: 10289 ký tự
# URL: 59 liên kết
# [176/407] Đang xử lý: Chua_Keo_Thai_Binh__Kien_truc_xa_xua_con_nguyen_ven_en_nay_-_iVIVU.com.html
# Nội dung: 5004 ký tự
# URL: 223 liên kết
# [177/407] Đang xử lý: Cam_nang_du_lich_Thua_Thien_Hue.html
# Nội dung: 24246 ký tự
# URL: 126 liên kết
# [178/407] Đang xử lý: Bai_bien_My_Khe__Wikipedia_tieng_Viet.html
# Nội dung: 1260 ký tự
# URL: 96 liên kết
# [179/407] Đang xử lý: Kham_pha_bai_a_co_Sapa_-_Net_ep_bi_an_thi_tran_mo_suong.html
# Nội dung: 11912 ký tự
# URL: 312 liên kết
# [180/407] Đang xử lý: Vuon_quoc_gia_Cuc_Phuong_Rung_nguyen_sinh_ep_nhat_Viet_Nam.html
# Nội dung: 12959 ký tự
# URL: 118 liên kết
# [181/407] Đang xử lý: Khu_du_lich_ai_Nam_Binh_Duong_-_Nhung_ki_luc_cuon_hut_du_khach.html
# Nội dung: 6038 ký tự
# URL: 81 liên kết
# [182/407] Đang xử lý: Quan_the_danh_thang_Trang_An__Wikipedia_tieng_Viet.html
# Nội dung: 38289 ký tự
# URL: 389 liên kết
# [183/407] Đang xử lý: Cam_nang_du_lich_ak_Nong.html
# Nội dung: 19376 ký tự
# URL: 68 liên kết
# [184/407] Đang xử lý: Kinh_nghiem_i_du_lich_doc_Viet_Nam_cua_khach_Tay.html
# Nội dung: 11422 ký tự
# URL: 191 liên kết
# [185/407] Đang xử lý: Hon_Mun__Wikipedia_tieng_Viet.html
# Nội dung: 4926 ký tự
# URL: 258 liên kết
# [186/407] Đang xử lý: Kinh_nghiem_du_lich_nui_Ba_Ra_cho_cac_oi_chan_nghien_xe_dich.html
# Nội dung: 8912 ký tự
# URL: 49 liên kết
# [187/407] Đang xử lý: Khu_Du_Lich_Suoi_Tien_Cap_nhat_gia_ve_va_hoat_ong_moi_2025.html
# Nội dung: 10438 ký tự
# URL: 46 liên kết
# [188/407] Đang xử lý: Cam_nang_du_lich_Cat_Ba.html
# Nội dung: 11990 ký tự
# URL: 76 liên kết
# [189/407] Đang xử lý: Cam_nang_du_lich_Sa_Pa.html
# Nội dung: 15610 ký tự
# URL: 99 liên kết
# [190/407] Đang xử lý: Cam_nang_du_lich_Bac_Kan.html
# Nội dung: 11621 ký tự
# URL: 63 liên kết
# [191/407] Đang xử lý: Kham_pha_Ho_Lak_-_Nang_tho_cua_nui_rung_Tay_Nguyen_hoang_da.html
# Nội dung: 9939 ký tự
# URL: 58 liên kết
# [192/407] Đang xử lý: Cu_Lao_Xanh__Vien_ngoc_xanh_an_minh_giua_bien_Quy_Nhon_-_MOTOGO.html
# Nội dung: 10935 ký tự
# URL: 58 liên kết
# [193/407] Đang xử lý: Cu_Lao_Xanh_-_Vien_ngoc_bien_hoang_so_tuyet_ep_o_Quy_Nhon.html
# Nội dung: 14857 ký tự
# URL: 76 liên kết
# [194/407] Đang xử lý: Cua_Lo__Wikipedia_tieng_Viet.html
# Nội dung: 2825 ký tự
# URL: 233 liên kết
# [195/407] Đang xử lý: Kinh_Nghiem_Du_Lich_Cu_Lao_Cham_Noi_Tieng_O_Hoi_An_-_Klook_Blog.html
# Nội dung: 7698 ký tự
# URL: 402 liên kết
# [196/407] Đang xử lý: Cam_nang_du_lich_Long_An.html
# Nội dung: 13200 ký tự
# URL: 69 liên kết
# [197/407] Đang xử lý: Huong_dan_uong_i_khu_du_lich_Buu_Long_ong_Nai_-_iVIVU.com.html
# Nội dung: 4491 ký tự
# URL: 210 liên kết
# [198/407] Đang xử lý: Khu_du_lich_Nui_Cam_An_Giang_ve_ep_linh_thieng_cua_nui_rung.html
# Nội dung: 10619 ký tự
# URL: 50 liên kết
# [199/407] Đang xử lý: Tam_ao__Wikipedia_tieng_Viet.html
# Nội dung: 10025 ký tự
# URL: 361 liên kết
# [200/407] Đang xử lý: Thanh_co_Quang_Tri_-_iem_en_linh_thieng_luu_giu_ky_uc_hao_hung_qua_81_ngay_em_-_iVIVU.com.html
# Nội dung: 4745 ký tự
# URL: 223 liên kết
# [201/407] Đang xử lý: Moc_Chau_(thi_xa)__Wikipedia_tieng_Viet.html
# Nội dung: 19458 ký tự
# URL: 462 liên kết
# [202/407] Đang xử lý: Vieng_tham_en_Tran_Nam_inh_-_cam_nhan_net_ep_Viet.html
# Nội dung: 11460 ký tự
# URL: 55 liên kết
# [203/407] Đang xử lý: Chua_Keo_Thai_Binh,_co_tu_tram_nam_noi_ta_ngan_song_Hong.html
# Nội dung: 9326 ký tự
# URL: 44 liên kết
# [204/407] Đang xử lý: Cam_nang_du_lich_Lang_Co.html
# Nội dung: 9946 ký tự
# URL: 80 liên kết
# [205/407] Đang xử lý: Kham_pha_Lang_gom_Bat_Trang_-_Hoi_tho_ngan_oi_cua_gom_su_Viet__Xanh_SM.html
# Nội dung: 11552 ký tự
# URL: 42 liên kết
# [206/407] Đang xử lý: Cam_nang_du_lich_Phu_Yen.html
# Nội dung: 19570 ký tự
# URL: 93 liên kết
# [207/407] Đang xử lý: Thuong_lam_Ben_Nha_Rong,_vung_ky_uc_rang_ngoi_cua_lich_su_dan_toc.html
# Nội dung: 7198 ký tự
# URL: 46 liên kết
# [208/407] Đang xử lý: Nui_Dinh_Vung_Tau_iem_en_sieu_ngau_cho_lan_au_trekking.html
# Nội dung: 10799 ký tự
# URL: 44 liên kết
# [209/407] Đang xử lý: Kinh_nghiem_du_lich_suoi_nuoc_nong_Kim_Boi_Hoa_Binh_chi_tiet.html
# Nội dung: 14466 ký tự
# URL: 60 liên kết
# [210/407] Đang xử lý: Khu_du_lich_Suoi_Tien_am_chat_huyen_thoai_ngay_ben_canh_Sai_Gon_-_iVIVU.com.html
# Nội dung: 5630 ký tự
# URL: 232 liên kết
# [211/407] Đang xử lý: Cam_nang_du_lich_Binh_Thuan.html
# Nội dung: 12683 ký tự
# URL: 68 liên kết
# [212/407] Đang xử lý: en_en_Tran_Nam_inh_ngam_nhin_kien_truc_chua_co_linh_thieng.html
# Nội dung: 8908 ký tự
# URL: 46 liên kết
# [213/407] Đang xử lý: Vuon_quoc_gia_YokDon,_iem_en_voi_nhung_trai_nghiem_kho_quen.html
# Nội dung: 8786 ký tự
# URL: 48 liên kết
# [214/407] Đang xử lý: Khu_du_lich_Suoi_Mo_-_ia_iem_da_ngoai_thu_vi_cuoi_tuan_-_BestPrice.html
# Nội dung: 6021 ký tự
# URL: 65 liên kết
# [215/407] Đang xử lý: Cam_nang_du_lich_Tam_ao.html
# Nội dung: 9896 ký tự
# URL: 58 liên kết
# [216/407] Đang xử lý: Sam_Son__Wikipedia_tieng_Viet.html
# Nội dung: 5246 ký tự
# URL: 282 liên kết
# [217/407] Đang xử lý: Ho_ong_Nai_3__Wikipedia_tieng_Viet.html
# Nội dung: 6232 ký tự
# URL: 107 liên kết
# [218/407] Đang xử lý: Kham_pha_lang_noi_Chau_oc_An_Giang_oc_ao.html
# Nội dung: 8236 ký tự
# URL: 159 liên kết
# [219/407] Đang xử lý: Khu_du_lich_danh_lam_thang_canh_Thac_Ban_Gioc.html
# Nội dung: 6415 ký tự
# URL: 32 liên kết
# [220/407] Đang xử lý: Cam_nang_du_lich_Chua_Bai_inh.html
# Nội dung: 13975 ký tự
# URL: 54 liên kết
# [221/407] Đang xử lý: Cam_nang_du_lich_Phu_Tho.html
# Nội dung: 10227 ký tự
# URL: 66 liên kết
# [222/407] Đang xử lý: Bai_Khem_Phu_Quoc_-_Ve_ep_tu_nhien_noi_ao_Ngoc.html
# Nội dung: 12565 ký tự
# URL: 309 liên kết
# [223/407] Đang xử lý: Vuon_Quoc_Gia_Ba_Vi_-_iem_du_lich_sieu_chat_gan_trung_tam_thu_o_-_Vntrip.vn.html
# Nội dung: 11682 ký tự
# URL: 80 liên kết
# [224/407] Đang xử lý: Kham_pha_Nha_tho_go_Kon_Tum_voi_tuoi_oi_hon_100_nam.html
# Nội dung: 8851 ký tự
# URL: 49 liên kết
# [225/407] Đang xử lý: Cam_nang_du_lich_Ha_Tinh.html
# Nội dung: 14905 ký tự
# URL: 75 liên kết
# [226/407] Đang xử lý: Kinh_nghiem_du_lich_vinh_Ha_Long_chi_tiet_nhat_2025.html
# Nội dung: 16198 ký tự
# URL: 70 liên kết
# [227/407] Đang xử lý: Cam_nang_du_lich_ia_oa_Cu_Chi.html
# Nội dung: 14774 ký tự
# URL: 177 liên kết
# [228/407] Đang xử lý: uong_len_cong_troi_Sapa_-_Noi_thien_uong_trong_may_ai_ngan.html
# Nội dung: 5491 ký tự
# URL: 46 liên kết
# [229/407] Đang xử lý: Dinh_oc_Lap_Gia_ve,_gio_mo_cua,_kien_truc_va_lich_su.html
# Nội dung: 20014 ký tự
# URL: 74 liên kết
# [230/407] Đang xử lý: eo_Hai_Van_-_Kham_pha_cung_uong_eo_ep_nhat_Viet_Nam.html
# Nội dung: 6775 ký tự
# URL: 65 liên kết
# [231/407] Đang xử lý: Cam_nang_du_lich_Tam_Coc_-_Bich_ong.html
# Nội dung: 10402 ký tự
# URL: 174 liên kết
# [232/407] Đang xử lý: Du_lich_Thanh_Co_Quang_Tri_-_Kham_pha_di_san_lich_su_van_hoa_Viet_Nam.html
# Nội dung: 9601 ký tự
# URL: 145 liên kết
# [233/407] Đang xử lý: Mieu_Ba_Chua_Xu_Nui_Sam_-_iem_du_lich_tam_lich_noi_tieng_cua_An_Giang.html
# Nội dung: 11881 ký tự
# URL: 51 liên kết
# [234/407] Đang xử lý: Chiem_nguong_ve_ep_hiem_co_o_Thac_Mo_Binh_Phuoc_-_HoaBinhTourist.html
# Nội dung: 6113 ký tự
# URL: 43 liên kết
# [235/407] Đang xử lý: Ly_Son__Wikipedia_tieng_Viet.html
# Nội dung: 12670 ký tự
# URL: 423 liên kết
# [236/407] Đang xử lý: Vinh_Lan_Ha__Wikipedia_tieng_Viet.html
# Nội dung: 2032 ký tự
# URL: 121 liên kết
# [237/407] Đang xử lý: Du_lich_am_O_Loan_iem_sang_cua_du_lich_Phu_Yen.html
# Nội dung: 9078 ký tự
# URL: 70 liên kết
# [238/407] Đang xử lý: Cau_Rong_a_Nang__Bieu_Tuong_Ruc_Ro_Cua_Thanh_Pho_Bien._-_MOTOGO.html
# Nội dung: 9195 ký tự
# URL: 59 liên kết
# [239/407] Đang xử lý: Kham_pha_Mai_Chau_Hoa_Binh_co_gi_cung_MIA.vn.html
# Nội dung: 9067 ký tự
# URL: 47 liên kết
# [240/407] Đang xử lý: Nhung_iem_en_du_lich_hap_dan_o_ong_Van_noi_Cao_nguyen_a_ai_ngan_-_Tinh_Ha_Giang_-_TRIPMAP.html
# Nội dung: 9468 ký tự
# URL: 96 liên kết
# [241/407] Đang xử lý: Cam_nang_du_lich_Nam_Du.html
# Nội dung: 10245 ký tự
# URL: 65 liên kết
# [242/407] Đang xử lý: Cam_nang_du_lich_en_Hung.html
# Nội dung: 14729 ký tự
# URL: 72 liên kết
# [243/407] Đang xử lý: Thap_Po_Klong_Garai__Wikipedia_tieng_Viet.html
# Nội dung: 8568 ký tự
# URL: 342 liên kết
# [244/407] Đang xử lý: Thac_Pongour__Wikipedia_tieng_Viet.html
# Nội dung: 6816 ký tự
# URL: 425 liên kết
# [245/407] Đang xử lý: Thap_Nhan_Phu_Yen_voi_ve_ep_van_hoa_Champa_xua_cu__Antamtour.vn.html
# Nội dung: 10405 ký tự
# URL: 88 liên kết
# [246/407] Đang xử lý: Cam_nang_du_lich_Con_ao.html
# Nội dung: 13367 ký tự
# URL: 85 liên kết
# [247/407] Đang xử lý: Cam_nang_du_lich_Binh_Phuoc.html
# Nội dung: 15842 ký tự
# URL: 60 liên kết
# [248/407] Đang xử lý: Phu_Quoc__Wikipedia_tieng_Viet.html
# Nội dung: 39486 ký tự
# URL: 618 liên kết
# [249/407] Đang xử lý: Review_Ganh_a_ia_Phu_Yen_va_nhung_trai_nghiem_thu_vi.html
# Nội dung: 8660 ký tự
# URL: 48 liên kết
# [250/407] Đang xử lý: Kinh_nghiem_du_lich_U_Minh_Ha_chi_tiet_cho_chuyen_i_nhan_tenh.html
# Nội dung: 9526 ký tự
# URL: 56 liên kết
# [251/407] Đang xử lý: Thac_Dai_Yem_iem_giai_nhiet_cho_mua_he_mat_lanh_tai_Moc_Chau.html
# Nội dung: 3019 ký tự
# URL: 92 liên kết
# [252/407] Đang xử lý: Vuon_quoc_gia_Phong_Nha__Ke_Bang__Wikipedia_tieng_Viet.html
# Nội dung: 69520 ký tự
# URL: 1077 liên kết
# [253/407] Đang xử lý: Cam_nang_du_lich_TP_Ho_Chi_Minh.html
# Nội dung: 23797 ký tự
# URL: 85 liên kết
# [254/407] Đang xử lý: Vinh_Ha_Long__Wikipedia_tieng_Viet.html
# Nội dung: 74318 ký tự
# URL: 1145 liên kết
# [255/407] Đang xử lý: Nha_tho_go_Kontum_hon_tram_tuoi_co_kinh_uy_nghiem.html
# Nội dung: 4323 ký tự
# URL: 211 liên kết
# [256/407] Đang xử lý: Hon_Kho_Quy_Nhon_iem_en_khong_the_bo_lo_khi_he_ve.html
# Nội dung: 14314 ký tự
# URL: 64 liên kết
# [257/407] Đang xử lý: Cam_nang_du_lich_Ca_Mau.html
# Nội dung: 14334 ký tự
# URL: 86 liên kết
# [258/407] Đang xử lý: Cam_nang_du_lich_Quang_Ninh.html
# Nội dung: 25790 ký tự
# URL: 98 liên kết
# [259/407] Đang xử lý: Cam_nang_du_lich_Tuyen_Quang.html
# Nội dung: 16624 ký tự
# URL: 69 liên kết
# [260/407] Đang xử lý: Cam_nang_du_lich_Phu_Quy.html
# Nội dung: 13157 ký tự
# URL: 87 liên kết
# [261/407] Đang xử lý: oi_che_Moc_Chau_-_iem_en_hap_dan_du_khach.html
# Nội dung: 14632 ký tự
# URL: 96 liên kết
# [262/407] Đang xử lý: Cam_nang_du_lich_Gia_Lai.html
# Nội dung: 17876 ký tự
# URL: 73 liên kết
# [263/407] Đang xử lý: Cho_noi_Nga_Nam__cho_noi_lau_oi_o_mien_song_nuoc_Soc_Trang.html
# Nội dung: 4035 ký tự
# URL: 207 liên kết
# [264/407] Đang xử lý: Thac_Ban_Gioc__Wikipedia_tieng_Viet.html
# Nội dung: 12296 ký tự
# URL: 399 liên kết
# [265/407] Đang xử lý: VUON_QUOC_GIA_BACH_MA,_vuon_quoc_gia_bach_ma.html
# Nội dung: 1992 ký tự
# URL: 53 liên kết
# [266/407] Đang xử lý: Du_lich_song_Huong,_Hue_-_Ban_giao_hoa_thien_nhien_va_van_hoa_vung_at_kinh_ky.html
# Nội dung: 5267 ký tự
# URL: 75 liên kết
# [267/407] Đang xử lý: Du_lich_o_Son_Hai_Phong,_thien_uong_nghi_duong_4_mua.html
# Nội dung: 12416 ký tự
# URL: 47 liên kết
# [268/407] Đang xử lý: 15_ia_iem_du_lich_Buon_Ma_Thuot_ep_quen_loi_ve_-_Vntrip.vn.html
# Nội dung: 9920 ký tự
# URL: 80 liên kết
# [269/407] Đang xử lý: Nui_Voi_Hai_Phong_-_iem_trekking_ngam_canh_danh_cho_hoi_yeu_kham_pha.html
# Nội dung: 15853 ký tự
# URL: 159 liên kết
# [270/407] Đang xử lý: Cam_nang_du_lich_Ho_Ba_Be.html
# Nội dung: 10633 ký tự
# URL: 58 liên kết
# [271/407] Đang xử lý: Chua_Tam_Chuc_-_Thong_tin_ay_u_nhat_ve_ngoi_chua_lon_nhat_Viet_Nam_-_MOTOGO.html
# Nội dung: 13124 ký tự
# URL: 67 liên kết
# [272/407] Đang xử lý: Ho_Xa_Huong__Canh_sac_tuyet_ep_tren_nui_Tam_ao_-_iVIVU.com.html
# Nội dung: 3648 ký tự
# URL: 226 liên kết
# [273/407] Đang xử lý: Kham_pha_ve_ep_tiem_an_bai_a_co_Sapa.html
# Nội dung: 6184 ký tự
# URL: 82 liên kết
# [274/407] Đang xử lý: Cam_nang_du_lich_ai_Lai.html
# Nội dung: 6607 ký tự
# URL: 56 liên kết
# [275/407] Đang xử lý: Hon_Mun_Cam_nang_vui_choi_voi_chi_phi_re_nhat.html
# Nội dung: 12165 ký tự
# URL: 78 liên kết
# [276/407] Đang xử lý: Trai_nghiem_i_Cho_Noi_Long_Xuyen_-_An_Giang.html
# Nội dung: 6752 ký tự
# URL: 50 liên kết
# [277/407] Đang xử lý: Kinh_nghiem_du_lich_cho_noi_Long_Xuyen_cho_chuyen_i_tron_ven.html
# Nội dung: 6042 ký tự
# URL: 61 liên kết
# [278/407] Đang xử lý: Nha_tho_con_ga_a_Lat__iem_nhan_kien_truc_cua_xu_so_ngan_hoa.html
# Nội dung: 9681 ký tự
# URL: 155 liên kết
# [279/407] Đang xử lý: Khu_du_lich_sinh_thai_Lang_Xanh_Ben_Tre.html
# Nội dung: 10037 ký tự
# URL: 140 liên kết
# [280/407] Đang xử lý: Chua_tham_thac_D'ray_Sap,_ban_chua_kham_pha_tron_Tay_Nguyen.html
# Nội dung: 7681 ký tự
# URL: 52 liên kết
# [281/407] Đang xử lý: Trang_chu_-_VQG_Cat_Tien.html
# Nội dung: 3552 ký tự
# URL: 70 liên kết
# [282/407] Đang xử lý: Cam_nang_du_lich_Binh_Lieu.html
# Nội dung: 9892 ký tự
# URL: 60 liên kết
# [283/407] Đang xử lý: Cam_nang_du_lich_Chua_Tam_Chuc.html
# Nội dung: 10983 ký tự
# URL: 60 liên kết
# [284/407] Đang xử lý: Trai_nghiem_i_Cho_Noi_Nga_Bay_-_iem_en_thu_vi_cua_Hau_Giang.html
# Nội dung: 6769 ký tự
# URL: 47 liên kết
# [285/407] Đang xử lý: Mieu_Ba_Chua_Xu_Nui_Sam_Chau_oc,_iem_en_tam_linh_tru_danh_Nam_Bo.html
# Nội dung: 10214 ký tự
# URL: 49 liên kết
# [286/407] Đang xử lý: Cam_nang_du_lich_Kien_Giang.html
# Nội dung: 16156 ký tự
# URL: 59 liên kết
# [287/407] Đang xử lý: Lang_gom_Bau_Truc__Mot_trong_nhung_lang_gom_co_xua_nhat_ong_Nam_A_tai_Ninh_Thuan_-_iVIVU.com.html
# Nội dung: 5228 ký tự
# URL: 226 liên kết
# [288/407] Đang xử lý: Gioi_thieu_ve_co_o_Hoa_Lu_voi_mot_thoi_huy_hoang_kinh_o_To_quoc.html
# Nội dung: 13026 ký tự
# URL: 88 liên kết
# [289/407] Đang xử lý: Nui_Dinh__Wikipedia_tieng_Viet.html
# Nội dung: 6521 ký tự
# URL: 121 liên kết
# [290/407] Đang xử lý: Ho_Nui_Coc__Wikipedia_tieng_Viet.html
# Nội dung: 10369 ký tự
# URL: 332 liên kết
# [291/407] Đang xử lý: oi_che_Moc_Chau_tua_tien_canh_trong_suong_som_-_Bao_VnExpress_Du_lich.html
# Nội dung: 8683 ký tự
# URL: 173 liên kết
# [292/407] Đang xử lý: Cam_nang_du_lich_Bac_Ninh.html
# Nội dung: 12273 ký tự
# URL: 73 liên kết
# [293/407] Đang xử lý: Cam_nang_du_lich_Hai_Phong.html
# Nội dung: 13441 ký tự
# URL: 80 liên kết
# [294/407] Đang xử lý: Goi_y_cho_ban_Top_3_oi_che_Moc_Chau_hap_dan_nhat.html
# Nội dung: 9316 ký tự
# URL: 114 liên kết
# [295/407] Đang xử lý: Cam_nang_du_lich_Phan_Thiet.html
# Nội dung: 9808 ký tự
# URL: 60 liên kết
# [296/407] Đang xử lý: Bo_tui_ngay_cam_nang_du_lich_Ben_Ninh_Kieu_-_Can_Tho.html
# Nội dung: 6564 ký tự
# URL: 58 liên kết
# [297/407] Đang xử lý: Khu_di_tich_Pac_Bo__Wikipedia_tieng_Viet.html
# Nội dung: 5852 ký tự
# URL: 290 liên kết
# [298/407] Đang xử lý: Cam_nang_du_lich_Soc_Trang.html
# Nội dung: 15473 ký tự
# URL: 178 liên kết
# [299/407] Đang xử lý: Review_Bao_Tang_ieu_Khac_Cham_Kho_Tang_Nghe_Thuat_O_a_Nang_-_Klook_Blog.html
# Nội dung: 7283 ký tự
# URL: 408 liên kết
# [300/407] Đang xử lý: Cam_nang_du_lich_Hai_Duong.html
# Nội dung: 17960 ký tự
# URL: 65 liên kết
# [301/407] Đang xử lý: Cam_nang_du_lich_a_Nang.html
# Nội dung: 28998 ký tự
# URL: 110 liên kết
# [302/407] Đang xử lý: Kham_pha_rung_tram_Tra_Su__An_Giang..html
# Nội dung: 5593 ký tự
# URL: 28 liên kết
# [303/407] Đang xử lý: Cam_nang_du_lich_Ninh_Chu.html
# Nội dung: 2953 ký tự
# URL: 165 liên kết
# [304/407] Đang xử lý: Cam_nang_du_lich_Ha_Giang.html
# Nội dung: 17824 ký tự
# URL: 83 liên kết
# [305/407] Đang xử lý: Quan_the_di_tich_va_danh_thang_Yen_Tu__Vinh_Nghiem__Con_Son,_Kiep_Bac__Wikipedia_tieng_Viet.html
# Nội dung: 9115 ký tự
# URL: 131 liên kết
# [306/407] Đang xử lý: Cam_nang_du_lich_Binh_Ba.html
# Nội dung: 12580 ký tự
# URL: 66 liên kết
# [307/407] Đang xử lý: Thanh_ia_My_Son__Wikipedia_tieng_Viet.html
# Nội dung: 16406 ký tự
# URL: 624 liên kết
# [308/407] Đang xử lý: Kinh_nghiem_tham_quan_Ben_Nha_Rong_noi_in_dau_chan_Bac.html
# Nội dung: 14463 ký tự
# URL: 91 liên kết
# [309/407] Đang xử lý: Pho_Co_Hoi_An_-_Thanh_pho_co_ep_hang_au_Chau_A_-_Vntrip.vn.html
# Nội dung: 10850 ký tự
# URL: 81 liên kết
# [310/407] Đang xử lý: Pho_Hien_Hung_Yen__Di_san_vang_bong_mot_thoi_-_iVIVU.com.html
# Nội dung: 4453 ký tự
# URL: 226 liên kết
# [311/407] Đang xử lý: Cam_nang_du_lich_ong_Nai.html
# Nội dung: 16611 ký tự
# URL: 74 liên kết
# [312/407] Đang xử lý: Cam_nang_du_lich_Y_Ty.html
# Nội dung: 9622 ký tự
# URL: 187 liên kết
# [313/407] Đang xử lý: Kham_pha_cho_Ben_Thanh,_bieu_tuong_lau_oi_cua_van_hoa_Sai_Gon.html
# Nội dung: 15133 ký tự
# URL: 47 liên kết
# [314/407] Đang xử lý: Cam_nang_du_lich_Tu_Le.html
# Nội dung: 8506 ký tự
# URL: 63 liên kết
# [315/407] Đang xử lý: Bai_Khem_Phu_Quoc__Kinh_nghiem_du_lich_kham_pha_chi_tiet_tu_A_-_Z.html
# Nội dung: 10848 ký tự
# URL: 94 liên kết
# [316/407] Đang xử lý: ong_Thien_uong__Wikipedia_tieng_Viet.html
# Nội dung: 4554 ký tự
# URL: 339 liên kết
# [317/407] Đang xử lý: Cam_nang_du_lich_Tram_Tau.html
# Nội dung: 11115 ký tự
# URL: 70 liên kết
# [318/407] Đang xử lý: Khu_di_tich_lich_su_va_danh_thang_Yen_Tu__Wikipedia_tieng_Viet.html
# Nội dung: 7959 ký tự
# URL: 560 liên kết
# [319/407] Đang xử lý: Cam_nang_du_lich_Nghe_An.html
# Nội dung: 16059 ký tự
# URL: 93 liên kết
# [320/407] Đang xử lý: 3_ngoi_lang_co_nep_minh_giua_long_cao_nguyen_a_Ha_Giang.html
# Nội dung: 5353 ký tự
# URL: 65 liên kết
# [321/407] Đang xử lý: Cam_nang_du_lich_Vuon_quoc_gia_Cuc_Phuong.html
# Nội dung: 15165 ký tự
# URL: 63 liên kết
# [322/407] Đang xử lý: Thanh_nha_Ho__Wikipedia_tieng_Viet.html
# Nội dung: 31492 ký tự
# URL: 725 liên kết
# [323/407] Đang xử lý: Kinh_nghiem_vui_choi_tai_khu_du_lich_suoi_khoang_Kim_Boi_tu_A_en_Z__Xanh_SM.html
# Nội dung: 11267 ký tự
# URL: 44 liên kết
# [324/407] Đang xử lý: Cam_nang_du_lich_Nui_Dinh.html
# Nội dung: 7821 ký tự
# URL: 193 liên kết
# [325/407] Đang xử lý: Cam_nang_du_lich_Can_Tho.html
# Nội dung: 17279 ký tự
# URL: 88 liên kết
# [326/407] Đang xử lý: Cau_Vang__Wikipedia_tieng_Viet.html
# Nội dung: 4827 ký tự
# URL: 132 liên kết
# [327/407] Đang xử lý: Hoi_quan_Phuc_Kien_Hoi_An_-_Di_san_van_hoa_ep_nhat_nhi_o_thi_co.html
# Nội dung: 6827 ký tự
# URL: 45 liên kết
# [328/407] Đang xử lý: Cam_nang_du_lich_Mui_Ne.html
# Nội dung: 12634 ký tự
# URL: 87 liên kết
# [329/407] Đang xử lý: Kham_pha_Khu_du_lich_Mui_Ca_Mau_tai_vung_cuc_Nam_To_quoc.html
# Nội dung: 9364 ký tự
# URL: 52 liên kết
# [330/407] Đang xử lý: Hang_En__Wikipedia_tieng_Viet.html
# Nội dung: 3541 ký tự
# URL: 275 liên kết
# [331/407] Đang xử lý: Ho_Tri_An__Wikipedia_tieng_Viet.html
# Nội dung: 1666 ký tự
# URL: 110 liên kết
# [332/407] Đang xử lý: Kham_pha_Toa_Thanh_Tay_Ninh__Cong_trinh_quan_trong_cua_ao_Cao_ai.html
# Nội dung: 11992 ký tự
# URL: 81 liên kết
# [333/407] Đang xử lý: Cam_nang_du_lich_Mui_Nghe.html
# Nội dung: 7773 ký tự
# URL: 186 liên kết
# [334/407] Đang xử lý: Du_lich_ao_Ngoc_Vung_Cam_nang_tu_A_en_Z_-_iVIVU.com.html
# Nội dung: 6550 ký tự
# URL: 227 liên kết
# [335/407] Đang xử lý: Cam_nang_du_lich_Vuon_quoc_gia_Bach_Ma.html
# Nội dung: 11454 ký tự
# URL: 61 liên kết
# [336/407] Đang xử lý: Cam_nang_du_lich_Tien_Giang.html
# Nội dung: 14067 ký tự
# URL: 67 liên kết
# [337/407] Đang xử lý: a_Lat__Wikipedia_tieng_Viet.html
# Nội dung: 87293 ký tự
# URL: 1248 liên kết
# [338/407] Đang xử lý: Khu_du_lich_Suoi_Mo_ong_Nai__iem_en_ly_tuong_vao_dip_cuoi_tuan.html
# Nội dung: 16480 ký tự
# URL: 149 liên kết
# [339/407] Đang xử lý: Cam_nang_du_lich_ak_LaK.html
# Nội dung: 16854 ký tự
# URL: 68 liên kết
# [340/407] Đang xử lý: Cam_nang_du_lich_ien_Bien.html
# Nội dung: 19594 ký tự
# URL: 73 liên kết
# [341/407] Đang xử lý: Chinh_phuc_thac_Tac_Tinh,_Lai_Chau_-_Chon_binh_yen_xanh.html
# Nội dung: 7906 ký tự
# URL: 55 liên kết
# [342/407] Đang xử lý: Kham_pha_net_ep_dan_da_ma_nen_tho_cua_am_O_Loan_Phu_Yen_-_iVIVU.com.html
# Nội dung: 2974 ký tự
# URL: 220 liên kết
# [343/407] Đang xử lý: Bien_Cua_ai_Hoi_An_-_An_tuong_mot_trong_25_bai_bien_ep_nhat_Chau_A.html
# Nội dung: 9095 ký tự
# URL: 45 liên kết
# [344/407] Đang xử lý: Ho_Tuyen_Lam_O_au_Kinh_Nghiem_i_Ho_Tuyen_Lam_O_a_Lat_-_Klook_Blog.html
# Nội dung: 7133 ký tự
# URL: 412 liên kết
# [345/407] Đang xử lý: Kinh_nghiem_du_lich_khu_bao_ton_thien_nhien_Van_Long.html
# Nội dung: 3964 ký tự
# URL: 67 liên kết
# [346/407] Đang xử lý: Suoi_nuoc_nong_Kim_Boi__Wikipedia_tieng_Viet.html
# Nội dung: 1762 ký tự
# URL: 91 liên kết
# [347/407] Đang xử lý: Bo_tui_kinh_nghiem_du_lich_ao_Ngoc_Vung_chi_tiet_nhat.html
# Nội dung: 9693 ký tự
# URL: 61 liên kết
# [348/407] Đang xử lý: Cam_nang_du_lich_a_Lat.html
# Nội dung: 8795 ký tự
# URL: 81 liên kết
# [349/407] Đang xử lý: Cam_nang_du_lich_Ben_Tre.html
# Nội dung: 10341 ký tự
# URL: 69 liên kết
# [350/407] Đang xử lý: Cam_nang_du_lich_ong_Van.html
# Nội dung: 15868 ký tự
# URL: 85 liên kết
# [351/407] Đang xử lý: Ho_Xuan_Huong_(ho_nuoc)__Wikipedia_tieng_Viet.html
# Nội dung: 5339 ký tự
# URL: 262 liên kết
# [352/407] Đang xử lý: Cam_nang_du_lich_Bac_Lieu.html
# Nội dung: 13518 ký tự
# URL: 68 liên kết
# [353/407] Đang xử lý: Cam_nang_du_lich_Nam_inh.html
# Nội dung: 14112 ký tự
# URL: 67 liên kết
# [354/407] Đang xử lý: Cam_nang_du_lich_Kon_Tum.html
# Nội dung: 11888 ký tự
# URL: 71 liên kết
# [355/407] Đang xử lý: Vuon_quoc_gia_Tram_Chim__Wikipedia_tieng_Viet.html
# Nội dung: 18638 ký tự
# URL: 454 liên kết
# [356/407] Đang xử lý: Thanh_ia_My_Son_-_Di_san_van_hoa_the_gioi_tai_Quang_Nam.html
# Nội dung: 13505 ký tự
# URL: 74 liên kết
# [357/407] Đang xử lý: Cam_nang_du_lich_Chau_oc.html
# Nội dung: 14777 ký tự
# URL: 70 liên kết
# [358/407] Đang xử lý: Cam_nang_du_lich_Mai_Chau.html
# Nội dung: 9822 ký tự
# URL: 69 liên kết
# [359/407] Đang xử lý: en_Hung_Phu_Tho_-_Di_tich_tam_linh,_thieng_lieng.html
# Nội dung: 11924 ký tự
# URL: 310 liên kết
# [360/407] Đang xử lý: Kinh_nghiem_du_lich_Lang_Co_cuc_ky_huu_ich.html
# Nội dung: 12583 ký tự
# URL: 68 liên kết
# [361/407] Đang xử lý: Trekking_Hang_En,_hanh_trinh_kham_pha_thien_nhien_hoang_so.html
# Nội dung: 14508 ký tự
# URL: 36 liên kết
# [362/407] Đang xử lý: Cam_nang_du_lich_Ky_Co.html
# Nội dung: 7492 ký tự
# URL: 65 liên kết
# [363/407] Đang xử lý: Chua_But_Thap_Bac_Ninh-_Chon_luu_giu_Bao_Vat_Phat_Giao_linh_thieng.html
# Nội dung: 12248 ký tự
# URL: 84 liên kết
# [364/407] Đang xử lý: Cam_nang_du_lich_Quan_Lan.html
# Nội dung: 9372 ký tự
# URL: 67 liên kết
# [365/407] Đang xử lý: Khu_Du_Lich_Buu_Long_Vinh_Ha_Long_Thu_Nho_Cua_Nam_Bo.html
# Nội dung: 13050 ký tự
# URL: 66 liên kết
# [366/407] Đang xử lý: Cam_nang_du_lich_Tra_Vinh.html
# Nội dung: 17327 ký tự
# URL: 70 liên kết
# [367/407] Đang xử lý: Dinh_Bao_ai_a_Lat_-_net_kien_truc_Phap_giua_rung_thong.html
# Nội dung: 5365 ký tự
# URL: 213 liên kết
# [368/407] Đang xử lý: Ruong_bac_thang_Mu_Cang_Chai__buc_tranh_kiet_tac_cua_con_nguoi_va_thien_nhien.html
# Nội dung: 4151 ký tự
# URL: 91 liên kết
# [369/407] Đang xử lý: Review_ai_Nam_Binh_Duong_-_iem_vui_choi_hot_nhat_dip_le.html
# Nội dung: 12117 ký tự
# URL: 304 liên kết
# [370/407] Đang xử lý: Mui_Ne__Wikipedia_tieng_Viet.html
# Nội dung: 9776 ký tự
# URL: 525 liên kết
# [371/407] Đang xử lý: Du_lich_Buon_Ma_Thuot_va_nhung_ieu_ban_se_nho_khi_roi_xa.html
# Nội dung: 11044 ký tự
# URL: 230 liên kết
# [372/407] Đang xử lý: Cot_co_Lung_Cu_Dau_an_thieng_thieng_noi_ia_au_To_quoc.html
# Nội dung: 4876 ký tự
# URL: 47 liên kết
# [373/407] Đang xử lý: Khu_du_lich_Ho_Lak_co_gi_ac_biet_ma_ai_en_cung_me_man__Xanh_SM.html
# Nội dung: 17041 ký tự
# URL: 50 liên kết
# [374/407] Đang xử lý: Cam_nang_du_lich_Co_To.html
# Nội dung: 12437 ký tự
# URL: 72 liên kết
# [375/407] Đang xử lý: Vuon_quoc_gia_Ben_En__Wikipedia_tieng_Viet.html
# Nội dung: 3354 ký tự
# URL: 343 liên kết
# [376/407] Đang xử lý: Cam_nang_du_lich_Ha_Long.html
# Nội dung: 17472 ký tự
# URL: 87 liên kết
# [377/407] Đang xử lý: Thac_Prenn__Wikipedia_tieng_Viet.html
# Nội dung: 7898 ký tự
# URL: 418 liên kết
# [378/407] Đang xử lý: Bao_tang_Lich_su_Thanh_pho_Ho_Chi_Minh_ia_chi,_Gia_ve,_Luu_y__Xanh_SM.html
# Nội dung: 10625 ký tự
# URL: 42 liên kết
# [379/407] Đang xử lý: Thac_Mo_Binh_Phuoc_Kham_pha_ve_ep_hiem_co_kho_tim.html
# Nội dung: 7181 ký tự
# URL: 63 liên kết
# [380/407] Đang xử lý: Ho_Lak__Wikipedia_tieng_Viet.html
# Nội dung: 6777 ký tự
# URL: 305 liên kết
# [381/407] Đang xử lý: Cong_thong_tin_ien_tu_tinh_Bac_Giang.html
# Nội dung: 6130 ký tự
# URL: 76 liên kết
# [382/407] Đang xử lý: Vuon_quoc_gia_Bach_Ma__Wikipedia_tieng_Viet.html
# Nội dung: 2910 ký tự
# URL: 180 liên kết
# [383/407] Đang xử lý: Cam_nang_du_lich_An_Giang.html
# Nội dung: 9230 ký tự
# URL: 63 liên kết
# [384/407] Đang xử lý: Cam_nang_du_lich_Lao_Cai.html
# Nội dung: 15663 ký tự
# URL: 79 liên kết
# [385/407] Đang xử lý: Cam_nang_du_lich_Nha_Trang.html
# Nội dung: 15115 ký tự
# URL: 88 liên kết
# [386/407] Đang xử lý: Cam_nang_du_lich_Mu_Cang_Chai.html
# Nội dung: 12198 ký tự
# URL: 80 liên kết
# [387/407] Đang xử lý: Cam_nang_du_lich_Quy_Nhon.html
# Nội dung: 15984 ký tự
# URL: 81 liên kết
# [388/407] Đang xử lý: [A_-_Z]_Trai_nghiem_&_kinh_nghiem_du_lich_nui_Ba_en_Tay_Ninh.html
# Nội dung: 43480 ký tự
# URL: 41 liên kết
# [389/407] Đang xử lý: Co_o_Hoa_Lu_-_Dau_an_vang_son_cua_mot_thoi_dan_toc_oai_hung.html
# Nội dung: 9860 ký tự
# URL: 47 liên kết
# [390/407] Đang xử lý: Cam_nang_du_lich_Vung_Tau.html
# Nội dung: 19033 ký tự
# URL: 73 liên kết
# [391/407] Đang xử lý: Choi_gi_o_Ban_ao_Son_Tra_a_Nang_-_Review_chi_tiet.html
# Nội dung: 9482 ký tự
# URL: 149 liên kết
# [392/407] Đang xử lý: Hang_Son_oong__Wikipedia_tieng_Viet.html
# Nội dung: 11388 ký tự
# URL: 429 liên kết
# [393/407] Đang xử lý: Ho_Dau_Tieng_-_ho_nuoc_nhan_tao_lon_nhat_Viet_Nam_-_Vntrip.vn.html
# Nội dung: 6029 ký tự
# URL: 92 liên kết
# [394/407] Đang xử lý: Hai_ngoi_chua_co_o_Bac_Ninh_uoc_UNESCO_vinh_danh_di_san_-_Bao_VnExpress.html
# Nội dung: 14400 ký tự
# URL: 175 liên kết
# [395/407] Đang xử lý: Ngu_Hanh_Son_a_Nang_Kinh_nghiem_du_lich_chi_tiet_nam_2025.html
# Nội dung: 22464 ký tự
# URL: 87 liên kết
# [396/407] Đang xử lý: Nui_Ham_Rong_Sapa_-_Ngon_nui_hinh_au_rong_noi_tieng_cua_thanh_pho_mo_suong.html
# Nội dung: 9385 ký tự
# URL: 45 liên kết
# [397/407] Đang xử lý: Cam_nang_du_lich_Thai_Nguyen.html
# Nội dung: 16749 ký tự
# URL: 62 liên kết
# [398/407] Đang xử lý: Chua_But_Thap-_net_ep_am_chat_chua_Viet_-_AllTours.html
# Nội dung: 16298 ký tự
# URL: 104 liên kết
# [399/407] Đang xử lý: Con_ao__Wikipedia_tieng_Viet.html
# Nội dung: 33630 ký tự
# URL: 777 liên kết
# [400/407] Đang xử lý: Ben_Ninh_Kieu_Can_Tho_Review_chi_tiet_tu_A_-_Z.html
# Nội dung: 15076 ký tự
# URL: 315 liên kết
# [401/407] Đang xử lý: Hon_Nua_Phu_Yen_-_iem_du_lich_moi_noi_tai_Phu_Yen.html
# Nội dung: 6886 ký tự
# URL: 54 liên kết
# [402/407] Đang xử lý: Pho_co_Hoi_An__Wikipedia_tieng_Viet.html
# Nội dung: 64957 ký tự
# URL: 855 liên kết
# [403/407] Đang xử lý: Khu_du_tru_sinh_quyen_rung_ngap_man_Can_Gio__Wikipedia_tieng_Viet.html
# Nội dung: 13434 ký tự
# URL: 501 liên kết
# [404/407] Đang xử lý: Trang_chu_-_Cong_thong_tin_Thanh_Pho_Ho_Chi_Minh.html
# Nội dung: 11931 ký tự
# URL: 191 liên kết
# [405/407] Đang xử lý: Ganh_a_ia__Wikipedia_tieng_Viet.html
# Nội dung: 8018 ký tự
# URL: 317 liên kết
# [406/407] Đang xử lý: Fansipan__Wikipedia_tieng_Viet.html
# Nội dung: 8390 ký tự
# URL: 305 liên kết
# [407/407] Đang xử lý: Nha_tho_uc_Ba__iem_du_lich_khong_the_bo_qua_khi_en_Sai_Gon.html
# Nội dung: 7446 ký tự
# URL: 89 liên kết
#
# Đã lưu 63089 URL vào: extracted_urls.csv

# %%
# BÁO CÁO KẾT QUẢ
def generate_report(results):
    success_count = sum(1 for r in results if r['success'])
    total_urls = sum(len(r['urls']) for r in results)
    total_clean_chars = sum(r['clean_length'] for r in results)
    
    print("\n" + "=" * 60)
    print("BÁO CÁO KẾT QUẢ XỬ LÝ")
    print("=" * 60)
    print(f"Tổng số file HTML: {len(results)}")
    print(f"File xử lý thành công: {success_count}")
    print(f"File thất bại: {len(results) - success_count}")
    print(f"Tổng số URL trích xuất: {total_urls}")
    print(f"Tổng ký tự văn bản sạch: {total_clean_chars:,}")
    
    # Hiển thị chi tiết 5 file đầu
    print(f"\nCHI TIẾT 5 FILE ĐẦU:")
    print("-" * 50)
    for i, result in enumerate(results[:5]):
        status = "success" if result['success'] else "fail"
        print(f"{status} {result['title'][:50]}...")
        print(f"Ký tự: {result['clean_length']} | URL: {len(result['urls'])}")

generate_report(results)
# Out:
# ============================================================
# BÁO CÁO KẾT QUẢ XỬ LÝ
# ============================================================
# Tổng số file HTML: 407
# File xử lý thành công: 407
# File thất bại: 0
# Tổng số URL trích xuất: 63089
# Tổng ký tự văn bản sạch: 4,954,701
#
# CHI TIẾT 5 FILE ĐẦU:
# --------------------------------------------------
# success Đảo Hòn Khoai ở Cà Mau - vùng biển và dải đất phía...
# Ký tự: 14457 | URL: 140
# success Kinh nghiệm khám phá hồ Đá Xanh Vũng Tàu chi tiết ...
# Ký tự: 8587 | URL: 104
# success Cẩm nang Du lịch SẦM SƠN 2025 từ A-Z: lưu trú, ăn ...
# Ký tự: 11554 | URL: 68
# success Cẩm nang Du lịch Bảo Lộc 2024 từ A-Z: Di chuyển, ă...
# Ký tự: 11357 | URL: 69
# success Biển Cà Ná: Bãi biển đẹp nên thơ của Phan Rang...
# Ký tự: 11115 | URL: 60

# %%
# KIỂM TRA KẾT QUẢ
def verify_results():
    
    txt_files = [f for f in os.listdir(OUTPUT_FOLDER) if f.endswith('.txt')]
    
    print(f"\nKIỂM TRA KẾT QUẢ:")
    print(f"Số file TXT đã tạo: {len(txt_files)}")
    
    # Kiểm tra 3 file đầu
    for txt_file in txt_files[:3]:
        file_path = os.path.join(OUTPUT_FOLDER, txt_file)
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.read()
        
        print(f"\n{txt_file}:")
        print(f"Độ dài: {len(content)} ký tự")
        print(f"Nội dung: {content[:100]}...")

verify_results()
# Out:
# KIỂM TRA KẾT QUẢ:
# Số file TXT đã tạo: 407
#
# Cam_nang_du_lich_Tam_Coc_-_Bich_ong.txt:
# Độ dài: 10402 ký tự
# Nội dung: vne-go discover shorts podcasts thời sự chính trị kỷ nguyên mới 80 năm quốc khánh dân sinh việc làm ...
#
# Cam_nang_du_lich_Chua_Tam_Chuc.txt:
# Độ dài: 10983 ký tự
# Nội dung: du lịch cẩm nang tam chúc 2 trở lại du lịch điều hướng nhanh đến tam chúc khi nào? di chuyển tham qu...
#
# Cam_nang_du_lich_Ky_Co.txt:
# Độ dài: 7492 ký tự
# Nội dung: du lịch cẩm nang kỳ co 2 trở lại du lịch điều hướng nhanh di chuyển chơi gì ăn gì lưu ý bãi kỳ co th...
